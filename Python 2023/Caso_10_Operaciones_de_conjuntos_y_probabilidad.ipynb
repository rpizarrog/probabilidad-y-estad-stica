# %% [markdown]
# <a href="https://colab.research.google.com/github/rpizarrog/probabilidad-y-estad-stica/blob/master/Python%202023/Caso_10_Operaciones_de_conjuntos_y_probabilidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descripción
#
# -   Se cargan las librerías necesarias para ejecutar funciones
# -   Generar conjuntos de datos
# -   Construir todo el espacio muestral llamado *S.muestra*
# -   Realizar operaciones de conjuntos
# -   Estimar probabilidades con los conjuntos.
# -   Interpretar probabilidades

# %% [markdown]
# # Marco teórico
#
# ## Operación Union U.
#
# El conjunto de todos los elementos que pertenecen a A o a B, o tanto a A como a B, se llama la unión de A y B y se escribe A ∪ B.
#
# En la unión si hay elementos repetidos sólo se deja uno de ellos.
#
# ![](images/union%20conjuntos.png)
#
# ## Operación intersección ∩
#
# El conjunto de todos los elementos que pertenecen simultáneamente a A y B se llama la intersección de A y B y se escribe A ∩ B.
#
# ![](images/interseccion-01.png)
#
# ## Operación diferencia -
#
# El conjunto que consiste en todos los elementos de A que no pertenecen a B se llama la diferencia de A y B y se escribe A -- B.
#
# ![](images/diferencia.png)
#
# ## Operación complemento [C ó ´]
#
# Son todos los conjuntos con los elementos que no están en A y se escribe A' ó C A. Son todos los elementos que faltan y que no están en A para complementar todo el espacio muestral.
#
# ![](images/complemento-01.png)

# %% [markdown]
# # Desarrollo
#
# ## Cargar librerías

# %%
# Cargar librerías
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from matplotlib_venn import venn3

# %% [markdown]
# ## Cargar datos

# %%
url = "https://raw.githubusercontent.com/rpizarrog/probabilidad-y-estad-stica/master/2023/datos/alumnos_actividades_extraescolares.csv"
datos = pd.read_csv(url)



print("Los nombres de datos (alumnos)")

print(datos.head(70))
# Out:
# Los nombres de datos (alumnos)
#                 nombres
# 0                ADRIAN
# 1             ALEJANDRO
# 2        ALEX SEBASTIAN
# 3                ALONZO
# 4               AMÉRICA
# 5                ANDREA
# 6       ANDREI MICHELLE
# 7       ANDRES MAURICIO
# 8         ÁNGEL EDUARDO
# 9          ANGEL IOVANY
# 10           ANGEL ZAID
# 11       ANTONIO MANUEL
# 12                BRUNO
# 13        CARLOS ALEXIS
# 14       CARLOS EDUARDO
# 15        CARLOS MANUEL
# 16             CRISTIAN
# 17                DIEGO
# 18     EMMANUEL EDUARDO
# 19              ENRIQUE
# 20                 GAEL
# 21           GAEL YIREH
# 22     HECTOR GUADALUPE
# 23      JAIME ALEJANDRO
# 24          JESÚS AARÓN
# 25        JESÚS ARMANDO
# 26       JOANA ABDALLAH
# 27         JORGE ADRIAN
# 28         JORGE ADRIÁN
# 29        JORGE ENRIQUE
# 30           JOSÉ ÁNGEL
# 31         JOSE EDUARDO
# 32          JOSÉ MANUEL
# 33          JOSÉ MIGUEL
# 34           JOSE PEDRO
# 35         JOSUE ULISES
# 36          JUAN EMILIO
# 37          JUAN MIGUEL
# 38         KEVIN ALEXIS
# 39          LOGAN ISAAC
# 40          LUIS ARTURO
# 41         LUIS ERNESTO
# 42           LUIS JARET
# 43     LUIS MAXIMILIANO
# 44               MANUEL
# 45        MANUEL ALEXIS
# 46       MANUEL ANTONIO
# 47        MARCO ANTONIO
# 48          MARIS DANAE
# 49         MIGUEL ANGEL
# 50         OMAR ANTONIO
# 51        OSCAR ENRIQUE
# 52       PABLO EMMANUEL
# 53      PAUL ALESSANDRO
# 54        RICARDO DAVID
# 55         SARAHI LUCIA
# 56  STEPHANIE JAQUELINE
# 57      ULISES RAYMUNDO

# %% [markdown]
# ## Crear conjuntos de varias disciplinas
# * FU : FUTBOL
# * BA : BASQUETBOL
# * VO : VOLEYBOL
# * TE : TENIS
# * AJ : AJEDREZ
# * AT : ATLETISMO
# * DA : DANZA
# * RO : RONDALLA
# * TEA : TEATRO

# %%
random.seed(2023)

nombres = datos["nombres"].tolist()
N = len(nombres)

# Barajar los nombres aleatoriamente
random.shuffle(nombres)


# Barajar los nombres aleatoriamente
random.shuffle(nombres)

# Hacerlo conjunto la lista de nombres
nombres = set(nombres)
print("Todos los nombres")
print(nombres)
print("\n")

FU = set(random.sample(nombres,  20))
print("Conjunto FU: FUTBOL")
print(FU)
n = len(FU)
print("La probabilidad de elegir a un alumno que sea de FUTBOL es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")

BA = set(random.sample(nombres,  12))
print("Conjunto BA: BASQUETBOL")
print(BA)
n = len(BA)
print("La probabilidad de elegir a un alumno que sea de BASQUETBOL es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")


VO = set(random.sample(nombres,  12))
print("Conjunto VO: VOLEYBOL")
print(VO)
n = len(VO)
print("La probabilidad de elegir a un alumno que sea de VOLEYBOL es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")

TE = set(random.sample(nombres,  10))
print("Conjunto TE: TENIS")
print(TE)
n = len(TE)
print("La probabilidad de elegir a un alumno que sea de TENIS es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")

AJ = set(random.sample(nombres,  8))
print("Conjunto AJ: AJEDREZ")
print(AJ)
n = len(AJ)
print("La probabilidad de elegir a un alumno que sea de AJEDREZ es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")

AT = set(random.sample(nombres,  16))
print("Conjunto AT: ATLETISMO")
print(AT)
n = len(AT)
print("La probabilidad de elegir a un alumno que sea de ATLETISMO es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")

DA = set(random.sample(nombres,  12))
print("Conjunto DA: DANZA")
print(DA)
n = len(DA)
print("La probabilidad de elegir a un alumno que sea de DANZA es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")

RO = set(random.sample(nombres,  14))
print("Conjunto RO: RONDALLA")
print(RO)
n = len(RO)
print("La probabilidad de elegir a un alumno que sea de RONDALLA es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")

TEA = set(random.sample(nombres,  9))
print("Conjunto TEA: TEATRO")
print(TEA)
n = len(DA)
print("La probabilidad de elegir a un alumno que sea de TEATRO es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")
print("\n")
# Out:
# Todos los nombres
# {'CARLOS MANUEL', 'JESÚS AARÓN', 'KEVIN ALEXIS', 'JUAN MIGUEL', 'JORGE ADRIAN', 'ALEX SEBASTIAN', 'MARCO ANTONIO', 'ADRIAN', 'DIEGO', 'LUIS MAXIMILIANO', 'ALONZO', 'MANUEL ALEXIS', 'PABLO EMMANUEL', 'ANDRES MAURICIO', 'JOSÉ ÁNGEL', 'ANDREA', 'MANUEL', 'ANGEL ZAID', 'CARLOS ALEXIS', 'EMMANUEL EDUARDO', 'JOSUE ULISES', 'ANDREI MICHELLE', 'JOSE EDUARDO', 'OMAR ANTONIO', 'PAUL ALESSANDRO', 'MIGUEL ANGEL', 'JOSE PEDRO', 'LUIS ERNESTO', 'JORGE ENRIQUE', 'ENRIQUE', 'LUIS ARTURO', 'ANTONIO MANUEL', 'HECTOR GUADALUPE', 'MANUEL ANTONIO', 'JOSÉ MANUEL', 'LOGAN ISAAC', 'ULISES RAYMUNDO', 'JESÚS ARMANDO', 'LUIS JARET', 'JOSÉ MIGUEL', 'CARLOS EDUARDO', 'GAEL YIREH', 'ÁNGEL EDUARDO', 'OSCAR ENRIQUE', 'SARAHI LUCIA', 'ANGEL IOVANY', 'JORGE ADRIÁN', 'AMÉRICA', 'BRUNO', 'STEPHANIE JAQUELINE', 'RICARDO DAVID', 'JAIME ALEJANDRO', 'JOANA ABDALLAH', 'MARIS DANAE', 'GAEL', 'ALEJANDRO', 'CRISTIAN', 'JUAN EMILIO'}
#
#
# Conjunto FU: FUTBOL
# {'JESÚS AARÓN', 'KEVIN ALEXIS', 'JORGE ADRIAN', 'MARCO ANTONIO', 'MANUEL ALEXIS', 'PABLO EMMANUEL', 'ANDRES MAURICIO', 'ANDREA', 'ANGEL ZAID', 'JOSE EDUARDO', 'PAUL ALESSANDRO', 'LUIS ERNESTO', 'JESÚS ARMANDO', 'ULISES RAYMUNDO', 'LUIS JARET', 'GAEL YIREH', 'ÁNGEL EDUARDO', 'BRUNO', 'STEPHANIE JAQUELINE', 'CRISTIAN'}
# La probabilidad de elegir a un alumno que sea de FUTBOL es:  20 / 58 = 0.3448 ≈ 34.48 %
#
#
# Conjunto BA: BASQUETBOL
# {'OSCAR ENRIQUE', 'CARLOS ALEXIS', 'ANGEL IOVANY', 'SARAHI LUCIA', 'JESÚS AARÓN', 'KEVIN ALEXIS', 'JUAN MIGUEL', 'OMAR ANTONIO', 'PAUL ALESSANDRO', 'MIGUEL ANGEL', 'JESÚS ARMANDO', 'LUIS JARET'}
# La probabilidad de elegir a un alumno que sea de BASQUETBOL es:  12 / 58 = 0.2069 ≈ 20.69 %
#
#
# Conjunto VO: VOLEYBOL
# {'ÁNGEL EDUARDO', 'OSCAR ENRIQUE', 'SARAHI LUCIA', 'MANUEL', 'HECTOR GUADALUPE', 'BRUNO', 'ANDREI MICHELLE', 'ADRIAN', 'JOSE EDUARDO', 'JOANA ABDALLAH', 'JESÚS ARMANDO', 'CRISTIAN'}
# La probabilidad de elegir a un alumno que sea de VOLEYBOL es:  12 / 58 = 0.2069 ≈ 20.69 %
#
#
# Conjunto TE: TENIS
# {'CARLOS ALEXIS', 'ANGEL ZAID', 'JOSÉ ÁNGEL', 'KEVIN ALEXIS', 'MANUEL ANTONIO', 'LUIS MAXIMILIANO', 'OMAR ANTONIO', 'ALONZO', 'CRISTIAN', 'ANDRES MAURICIO'}
# La probabilidad de elegir a un alumno que sea de TENIS es:  10 / 58 = 0.1724 ≈ 17.24 %
#
#
# Conjunto AJ: AJEDREZ
# {'JOSÉ ÁNGEL', 'RICARDO DAVID', 'ALEX SEBASTIAN', 'JOSÉ MANUEL', 'LUIS JARET', 'DIEGO', 'ALEJANDRO', 'JUAN EMILIO'}
# La probabilidad de elegir a un alumno que sea de AJEDREZ es:  8 / 58 = 0.1379 ≈ 13.79 %
#
#
# Conjunto AT: ATLETISMO
# {'ÁNGEL EDUARDO', 'JOSÉ ÁNGEL', 'SARAHI LUCIA', 'LUIS ARTURO', 'EMMANUEL EDUARDO', 'JUAN MIGUEL', 'BRUNO', 'JOSUE ULISES', 'ADRIAN', 'LUIS JARET', 'DIEGO', 'LOGAN ISAAC', 'JESÚS ARMANDO', 'ALEJANDRO', 'JUAN EMILIO', 'LUIS ERNESTO'}
# La probabilidad de elegir a un alumno que sea de ATLETISMO es:  16 / 58 = 0.2759 ≈ 27.59 %
#
#
# Conjunto DA: DANZA
# {'ANGEL ZAID', 'SARAHI LUCIA', 'LUIS ARTURO', 'JORGE ADRIÁN', 'KEVIN ALEXIS', 'JOSÉ MANUEL', 'MARCO ANTONIO', 'ALONZO', 'JOANA ABDALLAH', 'MIGUEL ANGEL', 'ULISES RAYMUNDO', 'ANDRES MAURICIO'}
# La probabilidad de elegir a un alumno que sea de DANZA es:  12 / 58 = 0.2069 ≈ 20.69 %
#
#
# Conjunto RO: RONDALLA
# {'ÁNGEL EDUARDO', 'OSCAR ENRIQUE', 'LUIS ARTURO', 'JORGE ADRIÁN', 'KEVIN ALEXIS', 'RICARDO DAVID', 'JOSUE ULISES', 'ALEX SEBASTIAN', 'DIEGO', 'OMAR ANTONIO', 'JOANA ABDALLAH', 'GAEL', 'ULISES RAYMUNDO', 'LUIS ERNESTO'}
# La probabilidad de elegir a un alumno que sea de RONDALLA es:  14 / 58 = 0.2414 ≈ 24.14 %
#
#
# Conjunto TEA: TEATRO
# {'ÁNGEL EDUARDO', 'OSCAR ENRIQUE', 'ANDREA', 'HECTOR GUADALUPE', 'KEVIN ALEXIS', 'STEPHANIE JAQUELINE', 'ADRIAN', 'PABLO EMMANUEL', 'JOSÉ MIGUEL'}
# La probabilidad de elegir a un alumno que sea de TEATRO es:  12 / 58 = 0.2069 ≈ 20.69 %
# <ipython-input-65-0fba2c0ff044>:19: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   FU = set(random.sample(nombres,  20))
# <ipython-input-65-0fba2c0ff044>:26: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   BA = set(random.sample(nombres,  12))
# <ipython-input-65-0fba2c0ff044>:34: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   VO = set(random.sample(nombres,  12))
# <ipython-input-65-0fba2c0ff044>:41: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   TE = set(random.sample(nombres,  10))
# <ipython-input-65-0fba2c0ff044>:48: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   AJ = set(random.sample(nombres,  8))
# <ipython-input-65-0fba2c0ff044>:55: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   AT = set(random.sample(nombres,  16))
# <ipython-input-65-0fba2c0ff044>:62: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   DA = set(random.sample(nombres,  12))
# <ipython-input-65-0fba2c0ff044>:69: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   RO = set(random.sample(nombres,  14))
# <ipython-input-65-0fba2c0ff044>:76: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   TEA = set(random.sample(nombres,  9))

# %% [markdown]
# ## Unión de conjuntos U
#
# ### Unión de FUTBOL con ATLETISMO

# %%
# FUTBOL U ATLETISMO
resultado = FU.union(AT)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de FUTBOL O ATLETISMO es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")


# Diagrama de Venn
venn2([FU, AT], ('FUTBOL', 'ATLETISMO'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos FUTBOL y ATLETISMO\nFU: {}\nAT: {}".format(FU, AT))
plt.show()
# Out:
# {'JESÚS AARÓN', 'JORGE ADRIAN', 'ALEX SEBASTIAN', 'MARCO ANTONIO', 'LUIS MAXIMILIANO', 'ADRIAN', 'JOSÉ MANUEL', 'ALONZO', 'LOGAN ISAAC', 'MANUEL ALEXIS', 'JESÚS ARMANDO', 'PABLO EMMANUEL', 'JOSÉ MIGUEL', 'CARLOS ALEXIS', 'ANGEL ZAID', 'SARAHI LUCIA', 'OSCAR ENRIQUE', 'MANUEL', 'BRUNO', 'EMMANUEL EDUARDO', 'ANDREI MICHELLE', 'JOSUE ULISES', 'JOSE EDUARDO', 'OMAR ANTONIO', 'CRISTIAN', 'PAUL ALESSANDRO', 'MIGUEL ANGEL', 'MARIS DANAE', 'ALEJANDRO', 'JOSE PEDRO', 'LUIS ERNESTO'}
# La probabilidad de elegir a un alumno que sea de FUTBOL O ATLETISMO es:  31 / 58 = 0.5345 ≈ 53.45 %

# %% [markdown]
# ### Unión de TEATRO con RONDALLA

# %%
# TEATRO U RONDALLA
resultado = TEA.union(RO)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de TATRO O RONDALLA es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")


# Diagrama de Venn
venn2([TEA, RO], ('TEATRO', 'RONDALLA'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos TEATRO y RONDALLA\nTEA: {}\nRO: {}".format(TEA, RO))
plt.show()
# Out:
# {'ENRIQUE', 'LUIS ARTURO', 'KEVIN ALEXIS', 'MANUEL ANTONIO', 'ALEX SEBASTIAN', 'JOSÉ MANUEL', 'ADRIAN', 'JESÚS ARMANDO', 'LUIS JARET', 'JOSÉ MIGUEL', 'GAEL YIREH', 'ANGEL ZAID', 'MANUEL', 'EMMANUEL EDUARDO', 'RICARDO DAVID', 'JOSUE ULISES', 'CRISTIAN', 'JOANA ABDALLAH', 'ALEJANDRO', 'JOSE PEDRO'}
# La probabilidad de elegir a un alumno que sea de TATRO O RONDALLA es:  20 / 58 = 0.3448 ≈ 34.48 %

# %% [markdown]
# ## AJEDREZ U TENIS

# %%
# AJEDREZ U TENIS
resultado = AJ.union(TE)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de AJEDREZ O TENIS es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")

# Diagrama de Venn
venn2([AJ, TE], ('AJEDREZ', 'TENIS'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos AJEDREZ y TENIS\nAJ: {}\nTE: {}".format(AJ, TE))
plt.show()
# Out:
# {'JOSÉ ÁNGEL', 'OSCAR ENRIQUE', 'MANUEL', 'ENRIQUE', 'KEVIN ALEXIS', 'BRUNO', 'STEPHANIE JAQUELINE', 'JORGE ADRIAN', 'RICARDO DAVID', 'ALEX SEBASTIAN', 'JOSE EDUARDO', 'LOGAN ISAAC', 'JOANA ABDALLAH', 'ANDRES MAURICIO', 'GAEL YIREH'}
# La probabilidad de elegir a un alumno que sea de AJEDREZ O TENIS es:  15 / 58 = 0.2586 ≈ 25.86 %

# %% [markdown]
# ### Intersección de conjuntos ⋂
# #### Intersección  de FUTBOL con ATLETISMO

# %%
# FUTBOL ⋂ ATLETISMO
resultado = FU.intersection(AT)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de FUTBOL y ATLETISMO es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")

# Diagrama de Venn
venn2([FU, AT], ('FUTBOL', 'ATLETISMO'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos FUTBOL y ATLETISMO\nFU: {}\nAT: {}".format(FU, AT))
plt.show()
# Out:
# {'CARLOS ALEXIS', 'JESÚS AARÓN', 'LUIS MAXIMILIANO', 'LOGAN ISAAC', 'PABLO EMMANUEL'}
# La probabilidad de elegir a un alumno que sea de FUTBOL y ATLETISMO es:  5 / 58 = 0.0862 ≈ 8.62 %

# %% [markdown]
# ### Intersección de BASQUETBOL con VOLEYBOL

# %%
# BASQUETBOL ⋂ VOLEYBOL
resultado = BA.intersection(VO)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de BASQUETBOL y VOLEYBOL es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")

# Diagrama de Venn
venn2([BA, VO], ('BASQUETBOL', 'VOLEYBOL'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos BASQUETBOL y VOLEYBOL\nBA: {}\nVO: {}".format(BA, VO))
plt.show()
# Out:
# {'STEPHANIE JAQUELINE', 'PAUL ALESSANDRO', 'GAEL'}
# La probabilidad de elegir a un alumno que sea de BASQUETBOL y VOLEYBOL es:  3 / 58 = 0.0517 ≈ 5.17 %

# %% [markdown]
# # Intersección AJEDREZ, RONDALLA Y TEATRO
#
# ¿cuál es la probabildia de elegir a un alumno que esté inscritp en AJEDREZ RONDALLA Y TEATRO?

# %%
# AJEDREZ ⋂ RONDALLA ⋂ TEATRO
resultado = (AJ.intersection(RO)).intersection(TEA)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de AJEDREZ, RONDALLA Y TEATRO es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")

print(AJ)
print(RO)
print(TEA)
# Diagrama de Venn
venn3([AJ, RO, TEA], ('AJEDREZ', 'RONDALLA', 'TEATRO'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos AJEDREZ, Y RONDALLA Y TEATRO\nAJ: {}\nRO: {}\nTEA: {}".format(AJ, RO, TEA))
plt.show()
# Out:
# set()
# La probabilidad de elegir a un alumno que sea de AJEDREZ, RONDALLA Y TEATRO es:  0 / 58 = 0.0 ≈ 0.0 %
# {'KEVIN ALEXIS', 'STEPHANIE JAQUELINE', 'JORGE ADRIAN', 'RICARDO DAVID', 'LOGAN ISAAC', 'JOANA ABDALLAH', 'ANDRES MAURICIO', 'GAEL YIREH'}
# {'ANGEL ZAID', 'ENRIQUE', 'EMMANUEL EDUARDO', 'MANUEL ANTONIO', 'JOSÉ MANUEL', 'ADRIAN', 'CRISTIAN', 'JOANA ABDALLAH', 'JESÚS ARMANDO', 'LUIS JARET', 'JOSE PEDRO', 'JOSÉ MIGUEL', 'GAEL YIREH', 'ALEJANDRO'}
# {'MANUEL', 'ENRIQUE', 'LUIS ARTURO', 'KEVIN ALEXIS', 'RICARDO DAVID', 'JOSUE ULISES', 'ALEX SEBASTIAN', 'ALEJANDRO', 'JOSE PEDRO'}

# %% [markdown]
# ## Diferencia de
#
# ### FUTBOL - BASQUETBOL
#
# ¿Cuál es la probabilidad de seleccionar a un alumno que esté en FUTBOL y que no esté en BASQUETBOL?

# %%
# FUTBOL - BASQUETBOL
resultado = (FU - BA)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de FUTBOL y que no esté en BASQUETBOL es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")

# Diagrama de Venn
venn2([FU, BA], ('FUTBOL', 'BASQUETBOL'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos FUTBOL y BASQUETBOL\nFU: {}\nBA: {}".format(FU, BA))
plt.show()
# Out:
# {'CARLOS ALEXIS', 'ANGEL ZAID', 'SARAHI LUCIA', 'JESÚS AARÓN', 'JORGE ADRIAN', 'ANDREI MICHELLE', 'JOSÉ MANUEL', 'MARCO ANTONIO', 'ADRIAN', 'LUIS MAXIMILIANO', 'JOSE EDUARDO', 'ALONZO', 'LOGAN ISAAC', 'MANUEL ALEXIS', 'JESÚS ARMANDO', 'PABLO EMMANUEL', 'JOSE PEDRO', 'LUIS ERNESTO'}
# La probabilidad de elegir a un alumno que sea de FUTBOL y que no esté en BASQUETBOL es:  18 / 58 = 0.3103 ≈ 31.03 %

# %% [markdown]
# BASQUETBOL - FUTBOL
#
# ¿Cuál es la probabilidad de seleccionar a un alumno que esté en BASQUETBOL y que no esté en FUTBOL?

# %%
# FUTBOL - BASQUETBOL
resultado = (BA - FU)
print(resultado)
n = len(resultado) # resulado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que sea de FUTBOL y que no esté en BASQUETBOL es: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")

# Diagrama de Venn
venn2([BA, FU], ('BASQUETBOL', 'FUTBOL'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos BASQUETBOL Y FUTBOL \nBA: {}\nFU: {}".format(BA, FU))
plt.show()
# Out:
# {'MANUEL', 'ANGEL IOVANY', 'JORGE ADRIÁN', 'KEVIN ALEXIS', 'EMMANUEL EDUARDO', 'STEPHANIE JAQUELINE', 'JOSUE ULISES', 'JAIME ALEJANDRO', 'GAEL', 'ANDRES MAURICIO'}
# La probabilidad de elegir a un alumno que sea de FUTBOL y que no esté en BASQUETBOL es:  10 / 58 = 0.1724 ≈ 17.24 %

# %% [markdown]
# ### Complemento de AJEDREZ
#
# Se representa C(AJEDREZ) ó AJEDREZ '
#
# ¿Cuál es la probabilidad de que un alumno no juegue AJEDREZ, o no esté inscrit en AJEDREZ?
#
# Para encontrar el complemento se puede restar de universo de nombres de alumnos los que están en AJEDREZ.

# %%
# alumnos - AJEDREZ = Complemento de AJEDREZ
resultado = (nombres - AJ)
print(resultado)
n = len(resultado) # resultado de la operación de conjuntos
print("La probabilidad de elegir a un alumno que no sea de AJEDREZ: ",n,"/",N,"=",np.round(n/N, 4), "≈", np.round(n/N * 100, 2), "%")

# Diagrama de Venn
venn2([nombres, AJ], ('nombres', 'AJEDREZ'))

# Mostrar los elementos de cada conjunto en el título
plt.title("Conjuntos nombres y AJEDREZ \nnombres: {}\nAJ: {}".format(nombres, AJ))
plt.show()
# Out:
# {'CARLOS MANUEL', 'JESÚS AARÓN', 'KEVIN ALEXIS', 'JUAN MIGUEL', 'JORGE ADRIAN', 'MARCO ANTONIO', 'ADRIAN', 'LUIS MAXIMILIANO', 'ALONZO', 'MANUEL ALEXIS', 'PABLO EMMANUEL', 'ANDRES MAURICIO', 'ANDREA', 'MANUEL', 'ANGEL ZAID', 'CARLOS ALEXIS', 'EMMANUEL EDUARDO', 'JOSUE ULISES', 'ANDREI MICHELLE', 'JOSE EDUARDO', 'OMAR ANTONIO', 'PAUL ALESSANDRO', 'MIGUEL ANGEL', 'JOSE PEDRO', 'LUIS ERNESTO', 'JORGE ENRIQUE', 'ENRIQUE', 'LUIS ARTURO', 'ANTONIO MANUEL', 'HECTOR GUADALUPE', 'MANUEL ANTONIO', 'LOGAN ISAAC', 'ULISES RAYMUNDO', 'JESÚS ARMANDO', 'JOSÉ MIGUEL', 'CARLOS EDUARDO', 'GAEL YIREH', 'ÁNGEL EDUARDO', 'OSCAR ENRIQUE', 'SARAHI LUCIA', 'ANGEL IOVANY', 'JORGE ADRIÁN', 'AMÉRICA', 'BRUNO', 'STEPHANIE JAQUELINE', 'JAIME ALEJANDRO', 'JOANA ABDALLAH', 'MARIS DANAE', 'GAEL', 'CRISTIAN'}
# La probabilidad de elegir a un alumno que no sea de AJEDREZ:  50 / 58 = 0.8621 ≈ 86.21 %
