# %% [markdown]
# <a href="https://colab.research.google.com/github/rpizarrog/probabilidad-y-estad-stica/blob/master/2024/Caso_29_Pruebas_de_hip%C3%B3tesis_contraste_Z_con_valores_cr%C3%ADticos_de_Z_y_p_prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Objetivo
#
# Realizar prueba de hipótesis de la media poblacional usando la distribución normal estandariza z.

# %% [markdown]
# # Descripción
#
# - Cargar librerías.
# - Cargar funciones para este caso.
# - Identificar y visualizar los valores críticos de z con ciertos niveles de confianza.
# - Identificar y visualizar la probabilidad de aceptación de hipótesos con *p_prueba* comparado contra la probabilidad *p_value* para aceptar  o rechazar $H_0$.
# - Identificar datos iniciales de ejercicios para prueba de hipótesis a dos colas, hipótesis nula alternativa.
# - Identificar datos inicales de ejercicios para prueba de hipótesis cola a la izquierda, hipótesis nula alternativa.
# - Identificar datos inicales de ejercicios para prueba de hipótesis cola a la derecha, hipótesis nula alternativa.
# - Interpretación de ejercicios y del caso

# %% [markdown]
# # Fundamento teórico
#
# La prueba de hipótesis es un método estadístico que se utiliza para tomar decisiones sobre las características de una población, basándose en la información obtenida de una muestra de esa población.
#
# ¿Existe relación de prueba de hipótesis con intervalos de confianza?
#
# La relación que existe entre los intervalos de confianza y la prueba de hipótesis es tal, que precisamente los valores de prueba deben estar en la zona de intervalo de confianza determinado y permite con ello hacer contraste de valores de prueba para aceptar o rechazar alguna hipótesis.
#
# La inferencia estadística basada en lograr la resolver la naturaleza de afirmaciones contradictorias está relacionada con la prueba de hipótesis.
#
# Estas afirmaciones contradictorias, tiene que ver con el concepto de declaración de hipótesis. A lo que da lugar el concepto de hipótesis estadística que lo define con claridad.
#
# Una hipótesis estadística o simplemente una hipótesis es una afirmación o aseveración sobre el valor de un solo parámetro (característica de una población o característica de una distribución de probabilidad)” (Devore, 2018, pág. 253).
#
# Una hipótesis estadística es una aseveración o conjetura con respecto a una o más poblaciones” (Mendenhall, Beaver, & Beaver, 2010, pág. 321).
#
#
# Un contraste o prueba de hipótesis, consiste en plantear dos hipótesis, la hipótesis nula $(H_0)$ y la hipótesis alternativa $(H_1)$, y luego recopilar evidencia en forma de datos para determinar si hay suficiente evidencia para rechazar la hipótesis nula en favor de la hipótesis alternativa.

# %% [markdown]
# ## Fórmula para calcular el valor de z para contraste o prueba contra z críticos
#
# Para calcular $z$ a contrastar se utiliza la fórmula siguiente:
#
# $$
# z = \frac{{\bar{x} - \mu}}{{\sigma / \sqrt{n}}}
# $$
#
# * $z$ es el valor de prueba de z a contrastar contra valores críticos.
# * $\bar{x}$ es la media de la muestra.
# * $\mu$ es  la media estimada de la población.
# * $\sigma$ es la desviación estándar de la población conocida.
# * $n$ es el tamaño de la muestra.

# %% [markdown]
# ## Proceso para prueba de hipótesis
#
# Proceso para realizar prueba de hipótesis:
#
# 1. Formulación de hipótesis: Se establecen la hipótesis nula $(H_0)$, que generalmente afirma que no hay efecto o diferencia, y la hipótesis alternativa $(H_1)$, que afirma lo contrario.
#
# 2. Selección de nivel de significancia: Se elige un nivel de significancia (α) que representa la probabilidad de cometer un error de tipo I al rechazar la hipótesis nula cuando es verdadera. Un valor común para alpha es $α$ es $0.05$.
#
#   En casos anteriores, al identificar intervalos de confianza se requería el nivel de confianza para determinar el valor de alfa.
#
# 3. Selección de prueba estadística: Se selecciona una prueba estadística apropiada basada en el tipo de datos y la naturaleza de la hipótesis.
#
# 4. Cálculo del estadístico de prueba: Se calcula el estadístico de prueba a partir de los datos de la muestra.
#
# 5. Decisión: Se compara el valor del estadístico de prueba con un valor crítico basado en la distribución de probabilidad bajo la hipótesis nula, o se calcula un valor $p$ que representa la probabilidad de obtener un estadístico de prueba al menos tan extremo como el observado si la hipótesis nula es verdadera.
#
# 6. Conclusión: Si el valor $p$ es menor que α, se rechaza la hipótesis nula en favor de la hipótesis alternativa. De lo contrario, no se puede rechazar la hipótesis nula.

# %% [markdown]
# ## Escenarios de declaración de hipótesis
#
# Ejemplos de declaración de hipótesis. Par declarar hipótesis se utiliza la expresión $H_0$ para designar hipótesis nula  la expresión $H_1$ o $H_a$ para idenificar la hipótesis alternativa.
#
# La hipótesis nula significa una negación a una afirmación que pretende cambiar lo ya conocido. La afirmación es producto de una pregunta de investigación, lo que da lugar a la hipótesis alternativa y la hipótesis nula es la negación.
#
# La hipótesis nula  hay que demostrar estadísticament que se pueda rchazar o seguir aceptando.
#
# ### Ejemplo 1:
#
# En el escenario del acusado, la pregunta de investigción sería: ¿es el acusado culpable?, la  $H_0$  es que el acusado es inocente, "*El acusado no es culplable*"; por consiguiente, la  $H_1$  no es inocente y por consecuencia, "*El acusado es culpable*".
#
# $$
# H_0:  \text{Acusado no es culplable}
# \\acusado=inocente
# $$
#
# $$
# H_1:  \text{Acusado es culplable}
# \\acusado ≠inocente
# $$
#
# Estadísticamente se tendría que tener elementos cuantificables de la variable inocente que se contrastarían con los elementos de acusaciones para aceptar o rechazar la hipótesis nula.
#
# ### Ejemplo 2:
#
# * En un primer escenario de este ejemplo, es estudiar la edad promedio de las personas $(μ)$, una hipótesis es suponer que la media de la edad de una población de personas podría ser que en promedio tengan 32 años $(μ=32)$, y la otra decir lo contrario, que la media no es 32 años $(μ≠32)$.
#
# Pregunta de investigación ¿es diferente la edad promedio de las personas de 32 años?, la hipótesis alternativa $H_a$ es la afirmación a esa pregunta: $H_a$: "*la edad promedio de las personas es diferente de 32 años*" la $H_0$ implica la negación; $H_0$: "*la edad promedio de las personas NO es diferente de 32 años*".
#
# $$
# H_0: \text{La edad promedio no es de 32 años}\\ edad = 32
# $$
#
# $$
# H_1: \text{La edad promedio es de 32 años}\\ edad \ne 32
# $$
#
# * Un segundo escenario pudiera ser que se afirme que la edad promedio (media de la edad en años) pudiera estar por encima o igual a 32 años $(μ≥32)$ y la segunda afirmación sería lo contrario, edad por debajo de 32 años. $(μ<32)$.
#
# $$
# H_0: \text{La edad promedio no es mayor o igual que 32 años}\\ edad < 32
# $$
#
# $$
# H_1: \text{La edad promedio es mayor o igual a 32 años}\\ edad \ge 32
# $$
#
# * Un tercer escenario de la edad promedio de una población sería a la inversa del segundo escenario, afirmar que la edad promedio esté por debajo o igual a 32 años $(μ ≤ 32)$ y la segunda afirmación sería lo contrario, edad por encima de 32 años. $(μ > 32)$.
#
# $$
# H_0: \text{La edad promedio no es menor o igual que 32 años}\\ edad > 32
# $$
#
# $$
# H_1: \text{La edad promedio es menor o igual a 32 años}\\ edad \le 32
# $$
#
#
# ### Ejemplo 3:
#
# Considere un escenario en donde se tiene que aprobar una vacuna nueva y se requiere hacer un experimento en una muestra de datos de personas y determinar si una vacuna es efectiva o no en un periodo de tiempo en donde las personas sean inmunes a cierta enfermedad.
#
# El resultado del experimento devuelve un valor de efectividad de una nueva vacuna de  0  a  100 %.
#
# Históricamente se tiene que una vacuna actual tiene una efectivad del  75 % o de  0.75 , es decir  75  de cada cien personas no se enferman poniéndose la vacuna.
#
# Un laboratorio imaginario lanza una nueva vacuna tratando de descartar la efectividad de la nueva vacuna haciendo pruebas.
#
# La preguna de investigación es: ¿La nueva vacuna es mas efectiva?
#
# Entonces se declaran hipótesis nula y alternativa.
#
# La efectividad de la actual vacuna es del  0.75  o menor, si hay alguna vacuna nueva para cambiar de vacuna debe tener una efectividad por encima del  0.75  de manera general.
#
# Frases para comprender hipótesis nula: "*la nueva vacuna no tiene ningún efecto y la tasa de prevención es menor o igual al  75 % (la tasa histórica)*"; y para la hipótesis alternativa: "*la nueva vacuna es efectiva y la tasa de prevención es mayor al 75%*".
#
# $$
# H_0: \text{No es efectiva la nueva vacuna}
# \\Efectividad ≤ 0.75
# $$
#
# $$
# H_1:  \text{Si es efeciva la nueva vacuna}
# \\Efectividad > 0.75
# $$
#
# Estadísticamente, hay que calcular el valor de la efectividad y contrastar con valores específicos para tomar la decisión de aceptar o rechazar $H_0$.

# %% [markdown]
# ## Tipos de hipótesis
#
# En estadística se puede declarar tres tipos de hipótesis:
#
# * hipótesis a dos colas, cuando el valor de significancia de *alpha* $α$ se reparte a ambos lados de la curva y conforme a la probabilidad;
#
# * cola a la izquierda cuando toda la probabilidad está del lado izquierdo y el valor del alpha $α$ es igual al complemento del valor de la confiabilidad.
#
# * cola a la derecha cuando toda la probabilidad está del lado derecho y el valor del alpha $α$ es igual al complemento del valor de la confiabilidad.
#
# De acuerdo la prueba de hipótesis se debe comparar un parámetro estimado de la población contra un valor crítico calculado.
#
# La decisión de aceptar la $H_0$ dependerá de la condición de comparación.
#
# |                 | Dos colas        | Cola a la izquierda | Cola a la derecha |
# |-----------------|------------------|----------------------|-------------------|
# | Acepta          | $H_0$: parámetro=valor | $H_0$: parámetro≥ valor | $H_0$: parámetro≤ valor |
# | Rechaza         | $H_a$: parámetro≠valor | $H_0$: parámetro< valor | $H_0$: parámetro> valor |
#
# Convirtiendo esta tabla a una declaración de una hipótesis en donde se busca indagar una media poblacional por ejemplo $μ$ comparada contra un valor de 68 a dos colas, cola izquierda o cola a la derecha.
#
# El operador de igualdad que define si es a dos colas, cola izquierda o cola derecha es el signo de igualdad:
# * '=': es a dos colas,. La expresión de la hipótesis nula $H_0$ sería *"NO es diferente a*".
# * '≥':   es cola a la izquierda o cola inferior. La expresión de la hipótesis nula $H_0$ sería *"NO es menor a*".
# * '≤':  es cola a la derecha o cola superior. La expresión de la hipótesis nula $H_0$ sería *"NO es mayor a*".
#
# |                 | Dos colas        | Cola a la izquierda | Cola a la derecha |
# |-----------------|------------------|----------------------|-------------------|
# | Acepta          | $H_0$: $\mu$=68 | $H_0$: $\mu$ ≥ 68 | $H_0$: $\mu$ ≤ 68 |
# | Rechaza         | $H_a$: $\mu$≠68 | $H_a$: $\mu$< 68 | $H_a$: $\mu$ > valor |
#
#
# ### Prueba de hipótesis contrastando z contra z críticos
#
# En la hipótesis de dos colas significa que se va a aceptar la hipótesis nula $H_0$ siempre y cuando el valor de $z$ calculado se encuentre entre dos valores críticos que son determinados a partir del valor del alfa divido entre dos. $∝⁄2$.
#
# En la hipótesis cola a la izquierda significa que se va a aceptar la hipótesis nula $H_0$ siempre y cuando el valor de $z$ calculado se encuentre por encima del valor crítico a la izquierda que es determinado a partir del valor del alfa $∝$.
#
# En la hipótesis cola a la derecha significa que se va a aceptar la hipótesis nula $H_0$ siempre y cuando el valor de $z$ calculado se encuentre por debajo del valor crítico a la derecha que es determinado a partir del valor del alfa $∝$.
#
# ### Prueba de hipótesis contrastando el valor de *p prueba*
#
# En una prueba de hipótesis, el valor $p$ (*p-value* en inglés) es la probabilidad de obtener un resultado igual al observado o más extremo, bajo la suposición de que la hipótesis nula es verdadera. En otras palabras, el valor $p$ es una medida de la evidencia en contra de la hipótesis nula.
#
# Un valor $p$ pequeño sugiere que la evidencia en contra de la hipótesis nula es fuerte, lo que lleva a rechazar la hipótesis nula en favor de la hipótesis alternativa. Por otro lado, un valor $p$ grande sugiere que la evidencia en contra de la hipótesis nula es débil, lo que lleva a no rechazar la hipótesis nula.
#
# El valor estadístico de *p.valor* se adopta para consolidar la decisión de aceptar o rechazar la hipótesis nula $H_0$. El *p.valor* o *p.value* se calcula en términos de una probabilidad como respaldo a la decisión tomada.
#
# El significado del estadístico *p.valor* es la probabilidad de aceptación o rechazo de la hipótesis nula $H_0$.
#
# Por ejemplo si una probabilidad *p de prueba* es menor que $0.05$ o *p_value* u otro valor de significancia hay que rechazar la hipótesis nula $H_0$, de lo contrario aceptar la $H_0$.
#
# Toda vez que se determine el valor estadístico de *p_prueba*, este se debe comparar contra un nivel de significancia establecido que comúmente  puede ser 0.05 (*p_value*) pero puede ser diferente.
#
# Entonces el algoritmo para aceptar o rechazar $H_0$ a dos colas con *p_value* sería de la siguiente manera:
#
#
# A un nivel de confianza del 95%
# $$
# \text{p_prueba = 0.40 y p.value = 0.05$
# $$
#
# $$
# \text{if (p_prueba < p.value)  Se rechaza H0}
# \\ \text{de lo contrario} \\
# \text{if (p_prueba ≥ p.value) Se acepta H0}
# $$
#
# $$
# \text{if (0.40 < 0.05)  Se rechaza H0}
# \\ \text{de lo contrario} \\
# \text{if (0.40 < 0.05) Se acepta H0}
# $$
#
# **Nota importante**:
#
# En la hipótesis a dos colas el valor de $p$ de prueba (*p_prueba*) que es la probabilidad calculalada con respecto a $z$,  se multiplica dos veces esa probabilidad (por ser a dos colas) para se contrastado contra el *p_value*.
#
# En la hipótesis de cola izquierda o derecha el valor de *p_prueba* es el resultado de la probabilidad con respecto a $z$ directamente contrastado contra *p_value*.

# %% [markdown]
# # Desarrollo
#
# Inicialmente, se cargan librerías y funciones
#
# Se visualizan los contrastes de los valores de z calculados contra los valores críticos de z extraídos a partir del nivel de confianza.
#
# Luego, se presentan diversos ejercicios de pruebas de hipótesis, calculando $z$  y contrastando contra los valor crítico de $z$.
#
# Posteriormente, con el contraste a través de *p.value* se confirma la decisón de la prueba de hipótesis realziada con los valores críticos.
#
# Finalmente se interpretan los resultados.

# %% [markdown]
# ## Cargar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# ## Cargar funciones

# %%
def f_aceptar_rechazar_Ho_dos_colas(valor_contraste, confianza, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = norm.pdf(x, 0, 1)

    alfa = 1 - confianza
    # Definir los valores críticos para un nivel de significancia del 5%
    z_critico_izquierda = norm.ppf(alfa / 2)
    z_critico_derecha = norm.ppf(1 - alfa / 2)

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado = valor_contraste

    # Visualización en los ejes proporcionados
    ax.plot(x, y, 'b-', label='Distribución Normal Estándar')
    ax.fill_between(x, 0, y, where=(x <= z_critico_izquierda), color='red', alpha=0.5, label='Área de Rechazo (izquierda)')
    ax.fill_between(x, 0, y, where=(x >= z_critico_derecha), color='red', alpha=0.5, label='Área de Rechazo (derecha)')
    ax.axvline(z_critico_izquierda, color='red', linestyle='--', label=f'Valor Crítico (izquierda): {z_critico_izquierda:.4f}')
    ax.axvline(z_critico_derecha, color='red', linestyle='--', label=f'Valor Crítico (derecha): {z_critico_derecha:.4f}')
    ax.axvline(z_calculado, color='green', linestyle='--', label=f'Valor Calculado: {z_calculado:.4f}')
    ax.set_xlabel('Z')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (Dos Colas)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

def f_aceptar_rechazar_Ho_cola_izquierda(valor_contraste, confianza, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = norm.pdf(x, 0, 1)

    alfa = 1 - confianza
    # Definir los valores críticos para un nivel de significancia del 5%
    z_critico_izquierda = norm.ppf(alfa )

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado = valor_contraste

    # Visualización en los ejes proporcionados
    ax.plot(x, y, 'b-', label='Distribución Normal Estándar')
    ax.fill_between(x, 0, y, where=(x <= z_critico_izquierda), color='red', alpha=0.5, label='Área de Rechazo (izquierda)')

    ax.axvline(z_critico_izquierda, color='red', linestyle='--', label=f'Valor Crítico (izquierda): {z_critico_izquierda:.4f}')
    ax.axvline(z_calculado, color='green', linestyle='--', label=f'Valor Calculado: {z_calculado:.4f}')
    ax.set_xlabel('Z')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (Cola Izquierda)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

def f_aceptar_rechazar_Ho_cola_derecha(valor_contraste, confianza, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = norm.pdf(x, 0, 1)

    alfa = 1 - confianza
    # Definir los valores críticos para un nivel de significancia del 5%
    z_critico_derecha = norm.ppf(1 - alfa )


    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado = valor_contraste

    # Visualización en los ejes proporcionados
    ax.plot(x, y, 'b-', label='Distribución Normal Estándar')

    ax.fill_between(x, 0, y, where=(x >= z_critico_derecha), color='red', alpha=0.5, label='Área de Rechazo (derecha)')

    ax.axvline(z_critico_derecha, color='red', linestyle='--', label=f'Valor Crítico (derecha): {z_critico_derecha:.4f}')
    ax.axvline(z_calculado, color='green', linestyle='--', label=f'Valor Calculado: {z_calculado:.4f}')
    ax.set_xlabel('Z')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis.(Cola Derecha)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)


# Función que visualiza la probabilidad con p_prueba en relación a p_value
#  a dos colas
def f_aceptar_rechazar_Ho_dos_colas_p_value(valor_contraste, confianza, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = norm.pdf(x, 0, 1)

    alfa = 1 - confianza
    # Definir las áreas para un nivel de significancia del 5%
    z_critico_izquierda = norm.ppf(alfa / 2)
    z_critico_derecha = norm.ppf(1 - alfa / 2)

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado_izq = -(abs(valor_contraste))
    z_calculado_der = abs(valor_contraste)

    p_value = np.round(alfa, 4)

    p_prueba = np.round(stats.norm.cdf(z_calculado_izq) + (1 - stats.norm.cdf(z_calculado_der)), 4)

    # Visualización en los ejes proporcionados
    ax.plot(x, y, 'b-', label='Distribución Normal Estándar'+';'+str(p_value)+';'+str(p_prueba))
    ax.fill_between(x, 0, y, where=(x <= z_critico_izquierda), color='red', alpha=0.5, label=f'p_value (izq):{(p_value/2):.4f}')
    ax.fill_between(x, 0, y, where=(x >= z_critico_derecha), color='red', alpha=0.5, label=f'p_value (der):{(p_value/2):.4f}; dos colas={p_value}')
    ax.fill_between(x, 0, y, where=(x <= z_calculado_izq), color='green', alpha=0.3, label=f'p prueba izq:{(p_prueba/2):.4f}')
    ax.fill_between(x, 0, y, where=(x >= z_calculado_der), color='green', alpha=0.3, label=f'p prueba der:{(p_prueba/2):.4f}; dos colas= {p_prueba}')
    ax.axvline(z_critico_izquierda, color='red', linestyle='--', label=f'Valor Z Crítico (izquierda): {z_critico_izquierda:.4f}')
    ax.axvline(z_critico_derecha, color='red', linestyle='--', label=f'Valor Z Crítico (derecha): {z_critico_derecha:.4f}')
    ax.axvline(z_calculado_izq, color='green', linestyle='--', label=f'Valor Z Calculado: {z_calculado_izq:.4f}')
    ax.axvline(z_calculado_der, color='green', linestyle='--', label=f'Valor Z Calculado: {z_calculado_der:.4f}')
    ax.set_xlabel('Z')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (Dos Colas)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)


# Esta función visualiza las probabilidad p_value y p_prueba a distintos niveles de confoanza
# Cola a la izquierda
def f_aceptar_rechazar_Ho_cola_izquierda_p_value(valor_contraste, confianza, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = norm.pdf(x, 0, 1)

    alfa = 1 - confianza
    # Definir las áreas para un nivel de significancia del 5%
    z_critico_izquierda = norm.ppf(alfa)
   # z_critico_derecha = norm.ppf(1 - alfa / 2)

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado_izq = valor_contraste
    #z_calculado_der = abs(valor_contraste)

    p_value = np.round(alfa, 4)

    #print (z_calculado_izq)
    #z_calculado_izq = -1.5
    p_prueba = np.round(stats.norm.cdf(z_calculado_izq), 4)
    #print (p_prueba)

    # p_prueba = np.round(stats.norm.cdf(z_calculado_izq), 4)

    # Visualización en los ejes proporcionados



    ax.plot(x, y, 'b-', label='Distribución Normal Estándar'+';'+str(p_value)+';'+str(p_prueba))
    ax.fill_between(x, 0, y, where=(x <= z_critico_izquierda), color='red', alpha=0.5, label=f'p_value (izq):{p_value:.4f}')
    #ax.fill_between(x, 0, y, where=(x >= z_critico_derecha), color='red', alpha=0.5, label=f'p_value (der):{(p_value):.4f}; dos colas={p_value}')
    ax.fill_between(x, 0, y, where=(x <= z_calculado_izq), color='green', alpha=0.3, label=f'p_prueba (izq):{p_prueba:.4f}')
    #ax.fill_between(x, 0, y, where=(x >= z_calculado_der), color='green', alpha=0.3, label=f'p prueba der:{(p_prueba):.4f}; dos colas= {p_prueba}')
    ax.axvline(z_critico_izquierda, color='red', linestyle='--', label=f'Valor Z Crítico (izquierda): {z_critico_izquierda:.4f}')
    #ax.axvline(z_critico_derecha, color='red', linestyle='--', label=f'Valor Z Crítico (derecha): {z_critico_derecha:.4f}')
    ax.axvline(z_calculado_izq, color='green', linestyle='--', label=f'Valor Z Calculado: {z_calculado_izq:.4f}')
    #ax.axvline(z_calculado_der, color='green', linestyle='--', label=f'Valor Z Calculado: {z_calculado_der:.4f}')
    ax.set_xlabel('Z')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (cola izquierda)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

# Esta función visualiza las probabilidad p_value y p_prueba a distintos niveles de confoanza
# Cola a la derecha
def f_aceptar_rechazar_Ho_cola_derecha_p_value(valor_contraste, confianza, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = norm.pdf(x, 0, 1)

    alfa = 1 - confianza
    # Definir las áreas para un nivel de significancia del 5%
    z_critico_derecha = norm.ppf(1 - alfa)
    #print (z_critico_derecha)

   # z_critico_derecha = norm.ppf(1 - alfa / 2)

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado_der = valor_contraste
    #z_calculado_der = abs(valor_contraste)

    p_value = np.round(alfa, 4)

    #print (z_calculado_izq)
    #z_calculado_izq = -1.5
    p_prueba = np.round(1 - stats.norm.cdf(z_calculado_der), 4)
    #print (p_prueba)

    # p_prueba = np.round(stats.norm.cdf(z_calculado_izq), 4)

    # Visualización en los ejes proporcionados



    ax.plot(x, y, 'b-', label='Distribución Normal Estándar'+';'+str(p_value)+';'+str(p_prueba))
    #ax.fill_between(x, 0, y, where=(x <= z_critico_izquierda), color='red', alpha=0.5, label=f'p_value (izq):{p_value:.4f}')
    ax.fill_between(x, 0, y, where=(x >= z_critico_derecha), color='red', alpha=0.5, label=f'p_value (der):{(p_value):.4f}')
    #ax.fill_between(x, 0, y, where=(x <= z_calculado_izq), color='green', alpha=0.3, label=f'p_prueba (izq):{p_prueba:.4f}')
    ax.fill_between(x, 0, y, where=(x >= z_calculado_der), color='green', alpha=0.3, label=f'p prueba der:{(p_prueba):.4f}')
    #ax.axvline(z_critico_izquierda, color='red', linestyle='--', label=f'Valor Z Crítico (izquierda): {z_critico_izquierda:.4f}')
    ax.axvline(z_critico_derecha, color='red', linestyle='--', label=f'Valor Z Crítico (derecha): {z_critico_derecha:.4f}')
    #ax.axvline(z_calculado_izq, color='green', linestyle='--', label=f'Valor Z Calculado: {z_calculado_izq:.4f}')
    ax.axvline(z_calculado_der, color='green', linestyle='--', label=f'Valor Z Calculado: {z_calculado_der:.4f}')
    ax.set_xlabel('Z')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (cola derecha)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

# Esta función devuelve la decisión de acepar o rechzar H0
# Recibe los parámetros: confianza, la media estimada de la pobación, la media de la muestra,
# la desviación estándar conocida de la pobación, el valor de n y el tipo para saber el valor de alfa
# y conocer los valores críticos de z
# Devuelve gráfica y la decisión de aceptar o rechazar Ho
def f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std_poblacion, n, tipo):

  decision = ""

  alfa = 1 - confianza
  # Es una hipótesis a dos colas
  if tipo == "D": # Es una hipótesis a dos colas
    z_critico = norm.ppf(1 - alfa / 2)
    z_calculado = (media_muestra - media_estimada) / (desv_std_poblacion / np.sqrt(n))

    print ("z critico", z_critico)
    print ("z calculado", z_calculado)
    if (z_calculado < -z_critico) or (z_calculado > z_critico):
      decision = "Se rechaza"
    else:
      decision = "Se acepta"

    # Manda llamar la gráfica con los valores cr´tics de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = z_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_dos_colas(valor_contraste, confianza, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  # Es una hipótesis cola izquierda
  if tipo == "I": # Es una hipótesis a la izquierda
    z_critico = norm.ppf(alfa)
    z_calculado = (media_muestra - media_estimada) / (desv_std_poblacion / np.sqrt(n))

    print ("z critico", z_critico)
    print ("z calculado", z_calculado)
    if (z_calculado < z_critico):
      decision = "Se rechaza"
    else:
      decision = "Se acepta"

    # Manda llamar la gráfica con los valores cíticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = z_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_izquierda(valor_contraste, confianza, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  # Es una hipótesis cola a la derecha
  if tipo == "R": # Es una hipótesis a la derecha
    z_critico = norm.ppf(1 - alfa)
    z_calculado = (media_muestra - media_estimada) / (desv_std_poblacion / np.sqrt(n))

    print ("z critico", z_critico)
    print ("z calculado", z_calculado)
    if (z_calculado > z_critico):
      decision = "Se rechaza"
    else:
      decision = "Se acepta"

    # Manda llamar la gráfica con los valores cíticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = z_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_derecha(valor_contraste, confianza, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()
  return decision


# Esta función devuelve la decisión de acepar o rechzar H0 conforme valores p_prueba
# Recibe los parámetros: confianza, la media estimada de la pobación, la media de la muestra,
# la desviación estándar conocida de la pobación, el valor de n y el tipo para saber el valor de alfa
# y conocer los valores críticos de z
# Devuelve gráfica y la decisión de aceptar o rechazar Ho
def f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, n, tipo):

  decision = ""

  alfa = 1 - confianza
  # Es una hipótesis a dos colas
  if tipo == "D": # Es una hipótesis a dos colas
    z_critico = norm.ppf(1 - alfa / 2)
    z_calculado = (media_muestra - media_estimada) / (desv_std_poblacion / np.sqrt(n))

    print ("z critico", z_critico)
    print ("z calculado", z_calculado)

    # Definir las áreas para un nivel de significancia del 10%, 5% o 1%
    z_critico_izquierda = norm.ppf(alfa / 2)
    z_critico_derecha = norm.ppf(1 - alfa / 2)

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado_izq = -(abs(z_calculado))
    z_calculado_der = abs(z_calculado)

    p_value = np.round(alfa, 4)

    p_prueba = np.round(stats.norm.cdf(z_calculado_izq) + (1 - stats.norm.cdf(z_calculado_der)), 4)

    print ("Valor de p_prueba", p_prueba)
    print ("Valor de p_value", p_value)
    print ("Valuando probabilidades ... ")
    f_evaluar_p_rueba_p_value_ho(p_prueba, p_value)

    # Manda llamar la gráfica con los valores críticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = z_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_dos_colas_p_value(z_calculado, confianza, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  # Es una hipótesis cola izquierda
  if tipo == "I": # Es una hipótesis cola a la izquierda
    z_critico = norm.ppf(alfa)
    z_calculado = (media_muestra - media_estimada) / (desv_std_poblacion / np.sqrt(n))

    print ("z critico", z_critico)
    print ("z calculado", z_calculado)

    # Definir las áreas para un nivel de significancia del 5%
    z_critico_izquierda = norm.ppf(alfa)
    #z_critico_derecha = norm.ppf(1 - alfa / 2)

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    z_calculado_izq = z_calculado
    #z_calculado_der = abs(z_calculado)

    p_value = np.round(alfa, 4)

    p_prueba = np.round(stats.norm.cdf(z_calculado_izq), 4)

    print ("Valor de p_prueba", p_prueba)
    print ("Valor de p_value", p_value)
    print ("Valuando probabilidades ... ")
    f_evaluar_p_rueba_p_value_ho(p_prueba, p_value)

    # Manda llamar la gráfica con los valores críticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = z_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_izquierda_p_value(z_calculado, confianza, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  # Es una hipótesis cola a la derecha
  if tipo == "R": # Es una hipótesis cola a la derecha
    z_critico = norm.ppf(1 - alfa)
    z_calculado = (media_muestra - media_estimada) / (desv_std_poblacion / np.sqrt(n))

    print ("z critico", z_critico)
    print ("z calculado", z_calculado)

    # Definir las áreas para un nivel de significancia del 10%, 5% o 1%
    #_critico_izquierda = norm.ppf(alfa)
    z_critico_derecha = norm.ppf(1 - alfa)

    # Valor de Z calculado, por el momento es un valor arbitrario solo para explicación
    #z_calculado_izq = z_calculado
    z_calculado_der = z_calculado

    p_value = np.round(1 - alfa, 4)

    p_prueba = np.round(1 - stats.norm.cdf(z_calculado_der), 4)

    print ("Valor de p_prueba", p_prueba)
    print ("Valor de p_value", p_value)
    print ("Valuando probabilidades ... ")
    f_evaluar_p_rueba_p_value_ho(p_prueba, p_value)

    # Manda llamar la gráfica con los valores críticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = z_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_derecha_p_value(z_calculado, confianza, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  return decision

def f_evaluar_p_rueba_p_value_ho(p_prueba, p_value):
  if (p_prueba < p_value):
    print ("Se rechaza Ho")
  else:
    print ("Se acepta Ho")

# %% [markdown]
# ## Valores críticos de $z$ para contraste
#
# Los valores críticos de $z$ es el valor de $z$ en el eje horizontal en donde se cruza con la curva de densidad de la distribución $z$ con respeco a una probabilidad. Ver visualizaciones las líneas punteadas en rojo y el cruce con el eje horizontal.
#
# La siguente tabla identifica los valores críticos de $z$ que servirán para contraste.
#
# Estos valores se pueden calcular con la función de python: :
#
# | Confianza | Alfa | Z (Dos colas) $α/2$ | Z (Izquierda)$α$ | Z (Derecha)$1-α$ |
# |-----------|------|---------------|----------------|--------------|
# | 0.90      | 0.10 | 1.644854      | -1.281552      | 1.281552     |
# | 0.95      | 0.05 | 1.959964      | -1.644854      | 1.644854     |
# | 0.99      | 0.01 | 2.575829      | -2.326348      | 2.326348     |
#
# Para extrar los valores críticos de $Z$ para diferentes niveles de confianza en Python, se puede utilizar la función *ppf()* de la distribución normal estándar de scipy.stats.
#
# Ejemplo Python: a distintos niveles de confianza del 90%, 95% y 99%:

# %%
confianza = [0.90, 0.95, 0.99]
alfa = [1 - c for c in confianza]

for c, a in zip(confianza, alfa):
    z_dos_colas = norm.ppf(1 - a / 2)
    z_izquierda = norm.ppf(a)
    z_derecha = norm.ppf(1 - a)
    print(f"Confianza: {c:.2f}, Alfa: {a:.2f}, Z (Dos colas): {z_dos_colas:.4f}, Z (Izquierda): {z_izquierda:.4f}, Z (Derecha): {z_derecha:.4f}")
# Out:
# Confianza: 0.90, Alfa: 0.10, Z (Dos colas): 1.6449, Z (Izquierda): -1.2816, Z (Derecha): 1.2816
# Confianza: 0.95, Alfa: 0.05, Z (Dos colas): 1.9600, Z (Izquierda): -1.6449, Z (Derecha): 1.6449
# Confianza: 0.99, Alfa: 0.01, Z (Dos colas): 2.5758, Z (Izquierda): -2.3263, Z (Derecha): 2.3263

# %% [markdown]
# Deben ser los mismos valores que la tabla.

# %% [markdown]
# ## Hipótesis a dos colas
#
# Se visualiza el valor de un $z$ arbitrariamente definido contrastado contra los valores críticos de $z$ extraídos a partir del nivel de confianza y del valor de alfa a dos colas.
#
# Los niveles de confianza son los radicionales al $90$%, $95$% y $99$% por lo que alfa se dive el $α/2$, tanto a la izuierda como a la derecha.

# %%
confianzas = [0.90, 0.95, 0.99]
valor_contraste = -2.5
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate([0.90, 0.95, 0.99]):
    f_aceptar_rechazar_Ho_dos_colas(valor_contraste, confianza, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si el valor del $z$ calculado (línea punteada verde) está dentro de zona de aceptación es decir entre las dos líneas rojas punteadas o los valores críticos de $z$, entonces se acepta la $H_0$, de lo contrario, se rechaza la $H_0$, sea cual sea la hipótesis y de acuerdo al contexto.
#
# Entonces ¿Cómo calcular el valor de $z$ contrastar con los valores críticos de $z$ de acuerdo a la probabilidad?.
#
# $$
# z = \frac{{\bar{x} - \mu}}{{\sigma / \sqrt{n}}}
# $$

# %% [markdown]
# Ahora se visualiza el contraste de la probabilidad de dos veces $z$ con respecto a *p_value*.
#
# Con un valor de $z$ definido como una constante por el momento como puede ser como puede ser $z=-2.5$, se calcula la probabilidad de que $z$ esté entre $-2.5$ y $2.5$, razón por la que se interpreta que es una probabilidad a dos colas. Los valores de z crítico que dividen la zona de aceptación y rechazo al $95$% de $-1.9599$ y $+1.9599$.
#
# Ahora bien la probabilidad es de $0.05$ que es el área de rechazo de una hipótesis nula; esta probabildia es $p_value = 0.05$ significa que el valor de la probabilidad encontrada de *p_prueba* con repecto a $z$ si es menor a *p_value* tal vez $0.05$ se rechaza la $H_0$.

# %%
confianza = 95/100
alfa = 1 - confianza

z_izq = -1.959963984540054
z_der =  1.959963984540054
# A dos colas

print ("Hipótesis a dos colas: ")
print ("p value")
print ("Probabilidad z = ", z_izq, " = ", np.round(stats.norm.cdf(z_izq), 4))
print ("Probabilidad z = ", z_der, " = ", np.round(1 - stats.norm.cdf(z_der), 4 ))
p_value = stats.norm.cdf(z_izq) + 1- stats.norm.cdf(z_der)
print ("p_value", np.round(p_value, 4))


z =  -2.5 # El mismo valor de contraste que lo visualmente
print()
print ("p prueba con respecto a z = ")
print ("Probabilidad z del lado izquierdo= ", z, " = ", np.round(stats.norm.cdf(z), 4))
print ("Probabilidad z del lado derecho= ", abs(z), " = ", np.round(1 - stats.norm.cdf(abs(z)), 4))


print ("p_prueba")
p_prueba = stats.norm.cdf(z) + (1 - stats.norm.cdf(abs(z)))

print ("p_prueba sumado porque es a dos colas", np.round(p_prueba, 4))

print ()
print ("La decisión de Ho es ...")
f_evaluar_p_rueba_p_value_ho(p_prueba, p_value)
# Out:
# Hipótesis a dos colas:
# p value
# Probabilidad z =  -1.959963984540054  =  0.025
# Probabilidad z =  1.959963984540054  =  0.025
# p_value 0.05
#
# p prueba con respecto a z =
# Probabilidad z del lado izquierdo=  -2.5  =  0.0062
# Probabilidad z del lado derecho=  2.5  =  0.0062
# p_prueba
# p_prueba sumado porque es a dos colas 0.0124
#
# La decisión de Ho es ...
# Se rechaza Ho

# %% [markdown]
# La siguiente llamada de la función *f_aceptar_rechazar_Ho_dos_colas_p_value()* visualiza las probabilidad de *p_value* que son de acuerdo a los niveles de confianza *(0.90, 0.95, 0.99)* y las probabilidades de *p_prueba* con respecto al mismo valor de $z=-2.5$ previamente inicializado, con ello  representar el contraste usando las probabilidades para aceptar o rechazar $H_0$ a dos colas.

# %%
## Llamando y visualziando contraste con p_prueba y p_value
confianzas = [0.90, 0.95, 0.99]
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate([0.90, 0.95, 0.99]):
  f_aceptar_rechazar_Ho_dos_colas_p_value(z, confianza, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# En el contraste usando *p_value* contra el *p de prueba* si el valor de área color verde y rojo (cafesito) es menor que el área roja entonces se rechaza $H_0$ de lo contrario, si el valor del área bajo la curva es mayor que el área roja entonces se acepta $H_0$.

# %% [markdown]
# ## Hipótesis cola a la izquierda
#
# Se visualiza el valor de un $z$ crítico arbitrariamente definido contrastado contra el valor de $z$ extraído a partir del nivel de confianza cola a la izquierda.
#
# Los niveles de confianza son los tradicionales al $90$%, $95$% y $99$% por lo que alfa $1-confianza$, solo a la izquierda.

# %%
confianzas = [0.90, 0.95, 0.99]
valor_critico = -1.5
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate(confianzas):
    f_aceptar_rechazar_Ho_cola_izquierda(valor_critico, confianza, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si el valor del $z$ (línea punteada verde) está dentro de zona de aceptación es decir, a la derecha de la línea roja punteada, entonces se acepta la $H_0$, de lo contrario se rechaza la $H_0$, sea cual sea la hipótesis y de acuerdo al contexto.
#
# Entonces, nuevamente, ¿cómo calcular el valor de $z$ y contrastarlo con los valores críticos de $z$ de acuerdo a la probabilidad?.
#
# $$
# z = \frac{{\bar{x} - \mu}}{{\sigma / \sqrt{n}}}
# $$

# %% [markdown]
# Ahora se visualiza el contraste de la probabilidad a la izquierda de  $z$  con respecto a *p_value*.
#
# Con un valor de  $z$  definido como una constante por el momento como puede ser como puede ser  $z= −1.5$ , se calcula la probabilidad de que $z$ solamente por la izquierda. El valor de $z$ para definir zona de aceptación o rechazo se toma el valor al 95% de $z= -1.6449$.
#
# Ahora bien la probabilidad es de  $0.05$  que es el área de rechazo de una hipótesis nula; esta probabilidad es  *p_value=0.05* significa que el valor de la probabilidad encontrada  *p_value* con repecto a $z$ si es menor a $0.05$ se rechaza la  $H_0$.

# %%
confianza = 95/100
alfa = 1 - confianza

z_izq = -1.6449
# cola a la izquierda

print ("Hipótesis cola a la izquierda: ")
print ("p value")
print ("Probabilidad z = ", z_izq, " = ", np.round(stats.norm.cdf(z_izq) , 4))
p_value = stats.norm.cdf(z_izq)
print ("p_value", np.round(p_value, 4))


z =  -1.5 # Usando el mismo valor de contraste
print()
print ("p prueba con respecto a z = ")
print ("Probabilidad z del lado izquierdo= ", z, " = ", np.round(stats.norm.cdf(z), 4))

print ("p_prueba")
p_prueba = stats.norm.cdf(z)

print ("p_prueba cola a la izquierda", np.round(p_prueba, 4))

print ()
print ("La decisión de Ho es ...")
f_evaluar_p_rueba_p_value_ho(p_prueba, p_value)
# Out:
# Hipótesis cola a la izquierda:
# p value
# Probabilidad z =  -1.6449  =  0.05
# p_value 0.05
#
# p prueba con respecto a z =
# Probabilidad z del lado izquierdo=  -1.5  =  0.0668
# p_prueba
# p_prueba cola a la izquierda 0.0668
#
# La decisión de Ho es ...
# Se acepta Ho

# %% [markdown]
# La siguiente llamada de la función *f_aceptar_rechazar_Ho_cola_izquierda_p_value()* visualiza las probabilidad de *p_value* que son de acuerdo a los niveles de confianza *(0.90, 0.95, 0.99)* y las probabilidades de *p_prueba* con respecto al mismo valor de $z=-1.5$ previamente inicializado, con ello  representar el contraste usando las probabilidades para aceptar o rechazar $H_0$ cola izquierda.

# %%
## Llamando y visualziando contraste con p_prueba y p_value

confianzas = [0.90, 0.95, 0.99]
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate([0.90, 0.95, 0.99]):
  f_aceptar_rechazar_Ho_cola_izquierda_p_value(z, confianza, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si el área en color verde es la probabilida de prueba con respecto a z es mayor se acepta $H_0$ de lo conrario se rechaza $H_0$.

# %% [markdown]
# ## Hipótesis cola a la derecha
#
# Se visualiza el valor de $z$  arbitrariamente definido contrastado contra el valor crítico de $z$ extraído a partir del nivel de confianza cola a la derecha.
#
# Los niveles de confianza son los tradicionales al $90$%, $95$% y $99$% por lo que alfa $1-confianza$, solo a la derecha.

# %%
confianzas = [0.90, 0.95, 0.99]
valor_critico = 1.5
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate(confianzas):
    f_aceptar_rechazar_Ho_cola_derecha(valor_critico, confianza, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si el valor del $z$ calculado (línea punteada verde) está dentro de zona de aceptación es decir, a la izquierda de la línea roja punteada, entonces se acepta la $H_0$, de lo contrario se rechaza la $H_0$, sea cual sea la hipótesis y de acuerdo al contexto.
#
# Entonces, nuevamente la pregunta, ¿cómo calcular el valor de $z$ y que pueda se contrastado contra los valores críticos de $z$ de acuerdo a la probabilidad?.
#
# $$
# z = \frac{{\bar{x} - \mu}}{{\sigma / \sqrt{n}}}
# $$

# %% [markdown]
# Ahora se visualiza el contraste de la probabilidad a la derecha de  $z$  con respecto a *p_value*.
#
# Con un valor de  $z$  definido como una constante por el momento como puede ser como puede ser  $z= 1.5$ , se calcula la probabilidad de que $z$ solamente por la derecha. El valor de $z$ para definir zona de aceptación o rechazo se toma el valor al 95% de $z= 1.6449$.
#
# Ahora bien la probabilidad es de  $0.05$  que es el área de rechazo de una hipótesis nula; esta probabilidad es  *p_value=0.05* significa que el valor de la probabilidad encontrada  *p_value* con repecto a $z$ si es menor a $0.05$ se rechaza la  $H_0$.

# %%
confianza = 95/100
alfa = 1 - confianza

z_der = 1.6449
# cola a la derecha

print ("Hipótesis cola a la derecha: ")
print ("p value")
print ("Probabilidad z = ", z_der, " = ", np.round(1 - stats.norm.cdf(z_der) , 4))
p_value = 1 - stats.norm.cdf(z_der)
print ("p_value", np.round(p_value, 4))


z =  1.5 # Usando el mismo valor de contraste
print()
print ("p prueba con respecto a z = ")
print ("Probabilidad z del lado derecho= ", z, " = ", np.round(1 - stats.norm.cdf(z), 4))

print ("p_prueba")
p_prueba = 1 - stats.norm.cdf(z)

print ("p_prueba cola a la derecha", np.round(p_prueba, 4))

print ()
print ("La decisión de Ho es ...")
f_evaluar_p_rueba_p_value_ho(p_prueba, p_value)
# Out:
# Hipótesis cola a la derecha:
# p value
# Probabilidad z =  1.6449  =  0.05
# p_value 0.05
#
# p prueba con respecto a z =
# Probabilidad z del lado derecho=  1.5  =  0.0668
# p_prueba
# p_prueba cola a la derecha 0.0668
#
# La decisión de Ho es ...
# Se acepta Ho

# %% [markdown]
# La siguiente llamada de la función *f_aceptar_rechazar_Ho_cola_derecha_p_value()* visualiza las probabilidad de *p_value* que son de acuerdo a los niveles de confianza *(0.90, 095, 0.99)* y las probabilidades de *p_prueba* con respecto al mism valor de $z=1.5$ prevaimente inicializado, con ello  representar el contraste usando las probabilidades para aceptar o rechazar $H_0$ cola izquierda.

# %%
## Llamando y visualziando contraste con p_prueba y p_value
confianzas = [0.90, 0.95, 0.99]
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate([0.90, 0.95, 0.99]):
  f_aceptar_rechazar_Ho_cola_derecha_p_value(z, confianza, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ejercicios
#
# Se presentan varios ejercicios de declarar hipótesis buscando aceptar o rechazar el valor de una media poblacional a partir de datos de una muestra.
#
# Las hipótesis serán a dos colas, cola izquierda y cola a la derecha.
#
# ### Ejercicio 1. Peso de estudiantes
#
# El objetivo es conocer si la media poblacional $\mu$ hipotéticamente estimada del peso promedio de estudiantes hombres en cierta escuela de educación superior es $68$ kilogramos.
#
# Una preguna de investigación tentativa asociada al objetivo sería algo como ¿la media del peso de los estudiantes es diferente a 68 kgs?.
#
# Como la pregunta de investigación es una afirmación de la hipótesis alterntativa esta se declara como  $H_a$: *"la media del peso de la población de estudiantes es diferente de 68 kgs.*", la hipótesis nula es la negación de esta hipótesis alternativa $H_0$: *"la media del peso de la población de estudiantes no es diferente de 68 kgs."*.
#
# $$
# H_0: \text{la media del peso de la población de estudiantes NO es diferente de 68 kgs.}
# $$
#
# $$
# H_a: \text{la media de la población de estudiantes SI es diferente de 68 kgs.}
# $$
#
# O bien con simbología estadística y/o matemática:
#
# $$
# H_0: \mu = 68
# $$
#
# $$
# H_a: \mu \ne 68
# $$
#
# De acuerdo a la declaración de hipótes es una hipótesis ... a dos colas entonces el valor de significancia de alpha es $\alpha/2$ a ambos lados de la curva.
#
# Ahora bien, como de los datos iniciales si se conoce la desviación estándar de una población entonces se utilizará la distribución z para conocer los valores críticos $z$ a la izquierda y z a la derecha que servirán para el contraste o la comparación.
#
# El nivel de confianza, para este ejercicio se establece que sea el $90$% lo cual indica que bajo un nivel de $90$% de confianza la madia del peso de los estudiantes es de $68$ kgs.
#
# Para este ejercicio, de la muestra se necesita saber los datos iniciales: el tamaño de la muestra $n=36$, la media tomada de la muestra del peso de los estudiantes $\bar{x}=67.5$ y la desviación estándar conocida de la población $σ=3.6$.
#
# #### Prueba de hipótesis con z calculado contrastado con z criticos
#
# ¿Cuál es el valor de z calculado?
#
# $$
# \begin{aligned}
# z &= \frac{\bar{x} - \mu}{\sigma/\sqrt{n}} \\
# &= \frac{67.5 - 68}{3.6/\sqrt{36}} \\
# &= \frac{-0.5}{3.6/6} \\
# &= \frac{-0.5}{0.6} \\
# &= -0.8333
# \end{aligned}
# $$
#
# El valor de $z$ calculado de $-0.8333$ está en zona de aceptación mayor a $-z$ critico por la izquierda y menor a $z$ crítico por la derecha, por lo que se anticipa aceptar la $H_0$ de que el peso de los estudiantes es igual a $68$.
#
# Al mandar llamar la función *f_aceptar_rechazar_ho()* con los parámetros adecuados indicándole que es a dos colas tipo='D' se conoce la decisión de aceptar o rechzar $H_0$.

# %%
# Los datos
H0 = "la media del peso de la población de estudiantes NO es diferente de 68 kgs."
confianza  = 90/100
media_estimada = 68 # Es la media de comparación
media_muestra = 67.5 # Es la media tomada de la muestra

desv_std_poblacion = 3.6 # Es la desviación estándar de la población conocida
n = 36 # El tamaño de la muestra

decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "D")

print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
# Out:
# z critico 1.6448536269514722
# z calculado -0.8333333333333334
# Se acepta H0: la media del peso de la población de estudiantes NO es diferente de 68 kgs. con nivel de confianza del 90.0 %

# %% [markdown]
# A cualquier nivel de confianza ya sea $90$%, $95$% o inclusive $99$% se acepta la hipotesis nula a dos colas: "*la media del peso de la población de estudiantes NO es diferente de 68 kgs.*", dado qu eel valor de $z$ calculado está en zona de confianza o de aceptación de $H_0$.
#
# Se puede deducir e inferir que un nivel de confianza del $90$%, la media del peso en kgs. de de la población de estudiante debe estar aproximado en 68 kgs, aquí es donde tiene relación con el intervalo de confianza.

# %% [markdown]
# #### Prueba de hipótesis con *p_value*
#
# Ahora ¿cuál es la probabilidad p de prueba a dos colas con el valor de $z$ calculado?, ¿es menor esa probabilidad que la probabilidad de acuerdo a alfa $α$ o p_value?, ¿se acepta o rechaza la $H_0$?
#
# Al llamar la función *f_aceptar_rechazar_ho_p_value_p_prueba()* se observa la probabilidad a dos colas y también la decisión de aceptar o rechazar.

# %%
confianza  = 90/100
print ("Con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "D")
# Out:
# Con nivel de confianza del 90.0 %
# z critico 1.6448536269514722
# z calculado -0.8333333333333334
# Valor de p_prueba 0.4047
# Valor de p_value 0.1
# Valuando probabilidades ...
# Se acepta Ho
# ''

# %% [markdown]
# Se observa en las gráficas la de la izquierda, la de confiablidad al $90$% que el área en color verde es mayor que el área color rojo cafesito de tal forma que se acepta $H_0$ y se confirma lo que se dedujo con párrafos atrás.

# %% [markdown]
# ### Ejercicio 2. Estatura de estudiantes
#
# Este ejericio, supone que se quiere probar la afirmación de que la altura promedio de los estudiantes de una universidad es menor que $\mu = 170$ cm. Para ello, se toma una muestra aleatoria de $n=25$ estudiantes y se obtiene una altura promedio de $\bar{x} = 168 cm$. Se sabe que la población tiene una desviación estándar de $\sigma= 5$ cm.
#
# La pregunta de investigación sería algo como este cuestionamiento: ¿es la altura de los estudiantes menor a 170 cms?. Se declaran las hipótesis nula y alternativa:
#
# $$
# H_0: \text{La atura de los estudiantes NO es menor que 170 cms}
# $$
#
# $$
# H_a: \text{La atura de los estudiantes es menor que 170 cms}
# $$
#
# o bien matemáticamente:
#
# $$
# H_0: \mu \ge 170
# $$
#
# $$
# H_a: \mu < 170
# $$
#
# Se define que es una hipótesis cola a la izquierda y se asume que es a un $95$% de confianza.
#
#
# #### Con valor crítico de z
#
# Al mandar llamar la función *f_aceptar_rechazar_ho()* con los parámetros adecuados indicándole que es cola a la izquierda tipo='I' se conoce la decisión de aceptar o rechzar $H_0$.
#
# Se inicializan los datos se hace la prueba al 95% de confianza.
#
# $$
# \begin{aligned}
# z &= \frac{\bar{x} - \mu}{\sigma/\sqrt{n}} \\
# &= \frac{168 - 170}{5/\sqrt{25}} \\
# &= \frac{-2}{5/5} \\
# &= \frac{-2}{1} \\
# &= -2.0
# \end{aligned}
# $$

# %%
# Los datos
H0 = "La atura de los estudiantes NO es menor que 170 cms"
confianza  = 95/100
media_estimada = 170 # Es la media de comparación
media_muestra = 168 # Es la media tomada de la muestra

desv_std_poblacion = 5 # Es la desviación estándar de la población conocida
n = 25 # El tamaño de la muestra

decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "I")

print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
# Out:
# z critico -1.6448536269514722
# z calculado -2.0
# Se rechaza H0: La atura de los estudiantes NO es menor que 170 cms con nivel de confianza del 95.0 %

# %% [markdown]
# La línea punteada en color verde se interpreta que se rechaza la $H_0$.
#
# Al rechazar $H_0$, se concluye que hay suficiente evidencia para afirmar que la altura promedio de los estudiantes es menor que 170.
#
# #### Usando p_value
#
# Nuevamente los cuestionamentos siguientes: ¿cuál es la probabilidad p de prueba cola a la izquierda con el valor de $z$ calculado?, ¿es menor esa probabilidad que la probabilidad de acuerdo a alfa $α$ o p_value?, ¿se acepta o rechaza la $H_0$?
#
# Al llamar la función *f_aceptar_rechazar_ho_p_value_p_prueba()* se observa la probabilidad cola a la izquierda y también la decisión de aceptar o rechazar.

# %%
confianza  = 95/100
print ("Con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "I")
# Out:
# Con nivel de confianza del 95.0 %
# z critico -1.6448536269514722
# z calculado -2.0
# Valor de p_prueba 0.0228
# Valor de p_value 0.05
# Valuando probabilidades ...
# Se rechaza Ho
# ''

# %% [markdown]
# Se observa en las gráficas de colas a la izquierda, la del centro, la de confiablidad al $95$%, que el área en color verde cafesito es menor que el área color rojo de tal forma que se rechaza $H_0$ y se confirma lo que se dedujo con párrafos atrás. La probabilidad de *p_prueba=0.0228* es menor que *p_value=0.05*

# %% [markdown]
# ### Ejercicio 3. Tiempo promedio de estudio de alumnos
#
# Se quiere probar la afirmación de que el tiempo promedio que los estudiantes universitarios pasan estudiando por día es mayor que $\mu 4$ horas. Se toma una muestra aleatoria de $n=36$ estudiantes y se obtiene un tiempo promedio de estudio de $\bar{x}=4.5$ horas. Se tiene a partir de la muestra una desviación estándar de $\sigma=1.2$ y se intuye y estima que esa sería la desviación estándar de la población.
#
# La pregunta de investigación sería algo como este cuestionamiento: ¿es el tiempo promedio que estudian los alumnos por encima de 4 horas?. Se declaran las hipótesis nula y alternativa:
#
# $$
# H_0: \text{Los alumnos NO estudian mas de 4 horas}
# $$
#
# $$
# H_a: \text{Los alumnos estudian mas de 4 horas}
# $$
#
# o bien matemáticamente:
#
# $$
# H_0: \mu \le 4
# $$
#
# $$
# H_a: \mu > 4
# $$
#
# Se define que es una hipótesis cola a la derecha y se asume que es a un $99$% de confianza.
#
#
# #### Con valor crítico de z
#
# $$
# \begin{aligned}
# z &= \frac{\bar{x} - \mu}{\sigma/\sqrt{n}} \\
# &= \frac{4.5 - 4}{1.2/\sqrt{36}} \\
# &= \frac{0.5}{1.2/6} \\
# &= \frac{0.5}{0.2} \\
# &= 2.5
# \end{aligned}
# $$
#
#
# Al mandar llamar la función *f_aceptar_rechazar_ho()* con los parámetros adecuados indicándole que es cola a la derecha tipo='R' (derecha) se conoce la decisión de aceptar o rechzar $H_0$.
#
# Se inicializan los datos se hace la prueba al 99% de confianza.

# %%
# Los datos
H0 = "Los alumnos NO estudian mas de 4 horas"
confianza  = 99/100
media_estimada = 4 # Es la media de comparación
media_muestra = 4.5 # Es la media tomada de la muestra

desv_std_poblacion = 1.2 # Es la desviación estándar de la población conocida
n = 36 # El tamaño de la muestra

decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "R")

print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
# Out:
# z critico 2.3263478740408408
# z calculado 2.5
# Se rechaza H0: Los alumnos NO estudian mas de 4 horas con nivel de confianza del 99.0 %

# %% [markdown]
# La línea punteada en color verde está más a la derecha de la línea que representa en valor crítico de $z$.
#
# A todos los niveles de confianza como el $90$%, $95$% y $99$% la hipótesis $H_0$ se rechazaría.
#
# #### Usando p_value
#
# Nuevamente los cuestionamentos siguientes: ¿cuál es la probabilidad p de prueba cola a la derecha con el valor de $z$ calculado?, ¿es menor esa probabilidad que la probabilidad de acuerdo a alfa $α$ o p_value?, ¿se acepta o rechaza la $H_0$?
#
# Al llamar la función *f_aceptar_rechazar_ho_p_value_p_prueba()* con los argumento y *tipo = 'R'*,  se observa la probabilidad cola a la derecha y también la decisión de aceptar o rechazar.

# %%
confianza  = 99/100
print ("Con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "R")
# Out:
# Con nivel de confianza del 99.0 %
# z critico 2.3263478740408408
# z calculado 2.5
# Valor de p_prueba 0.0062
# Valor de p_value 0.99
# Valuando probabilidades ...
# Se rechaza Ho
# ''

# %% [markdown]
# Al $99$% de confianza el valor de *p_value es 0.01* y el valor de la probabilida de prueba es $0.0062$ por lo que es mucho menor, de tal forma que se rechaza $H_0$. El área bajo la curva en color verde cafesito es mucho menor que el área de color rojo.

# %% [markdown]
# ### Ejercicio 4 Nuevo tratamiento de medimento para la presión. Realizar.
#
# Se tiene un interés de probar si un nuevo tratamiento para reducir la presión arterial tiene algún efecto significativo en los pacientes.
#
# Habiendo aplicado el nuevo tratamiento se tomaron muestras de la presión arterial y estas fueron las medias estadísticas:
#
# {130, 125, 132, 128, 135, 130, 127, 131, 129, 133, 134, 135, 138, 128, 130, 132, 142,130, 128, 135, 126, 132, 134, 135, 129, 132, 128, 130, 132, 130}
#
# El experimento trata de evaluar si el nuevo medicamento en relación a controlar la presión.
#
# El valor de contraste es 130 es decir $\mu=130$.
#
# * Hipótesis a dos colas
# $$
# H_0: \text{El nuevo medicamente NO es diferente y controla la presión a 130}
# $$
#
# $$
# H_1: \text{El nuevo medicamento es diferente de 130}
# $$
#
# $$
# H_0: \mu = 130 \\
# H_1: \mu \ne 130
# $$
#
#
# * Hipótesis a cola izquierda
# $$
# H_0: \text{El nuevo medicamento NO es menor que 130}
# $$
#
# $$
# H_2: \text{El nuevo medicamento es menor  130}
# $$
#
# $$
# H_0: \mu \ge 130 \\
# H_2: \mu < 130
# $$
#
# * Hipótesis a cola derecha
#
# $$
# H_0: \text{El nuevo medicamento NO es mayor que 130 }
# $$
#
# $$
# H_2: \text{El nuevo medicamento es mayor que 130}
# $$
#
# $$
# H_0: \mu \le 130 \\
# H_2: \mu > 130
# $$
#
#
# El nivel de confianza para todas las hipótesis será del $99$%, o lo que es lo mismo, $\alpha=1 - 0.99 = 0.01$

# %%
datos = [130, 125, 132, 128, 135, 130,
         127, 131, 129, 133, 134, 135,
         138, 128, 130, 132, 142, 130,
         128, 135, 126, 132, 134, 135,
         129, 132, 128, 130, 132, 130]

n = len(datos)
confianza = 99/100 # 99% de confianza
media_estimada = 130 # Es la media de comparación
media_muestra = np.mean(datos) # Es la media tomada de la muestra
desv_std_poblacion = np.std(datos) # Es la desviación estándar que se obtiene de la muestra y se estima que así es en la población

print ("Datos iniciales")
print ("Confianza %: ", confianza* 100, "; relativo", confianza)
print ("n:", n)
print ("media_estimada:", media_estimada)
print ("media_muestra:", media_muestra)
print ("desv_std_poblacion:", desv_std_poblacion )
# Out:
# Datos iniciales
# Confianza %:  99.0 ; relativo 0.99
# n: 30
# media_estimada: 130
# media_muestra: 131.33333333333334
# desv_std_poblacion: 3.5808130671988767

# %% [markdown]
# #### ¿Se aprueba o rechaza hipótesis nula a dos colas?

# %%
H0 = "El nuevo medicamento es diferente de 130"
decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "D")

print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "D")
# Out:
# z critico 2.5758293035489004
# z calculado 2.039471845179307
# Se acepta H0: El nuevo medicamento es diferente de 130 con nivel de confianza del 99.0 %
# z critico 2.5758293035489004
# z calculado 2.039471845179307
# Valor de p_prueba 0.0414
# Valor de p_value 0.01
# Valuando probabilidades ...
# Se acepta Ho
# ''

# %% [markdown]
# No hay evidencia estadística suficiente para rechazar $H_0$, por lo que se acepta $H_0$ a dos colas.
#
# En otras palabras, con un nivel de confianza del 99%, no se puede concluir que la media de la población sea diferente de 130 basándose en los datos de la muestra.

# %% [markdown]
# #### ¿Se aprueba o rechaza hipótesis nula cola izquierda?

# %%
H0 = "El nuevo medicamento NO es menor que 130"
decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "I")
print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "I")
# Out:
# z critico -2.3263478740408408
# z calculado 2.039471845179307
# Se acepta H0: El nuevo medicamento NO es menor que 130 con nivel de confianza del 99.0 %
# z critico -2.3263478740408408
# z calculado 2.039471845179307
# Valor de p_prueba 0.9793
# Valor de p_value 0.01
# Valuando probabilidades ...
# Se acepta Ho
# ''

# %% [markdown]
# No hay evidencia estadística suficiente para rechazar $H_0$, por lo que se acepta $H_0$ cola a la izquierda.

# %% [markdown]
# #### ¿Se aprueba o rechaza hipótesis nula cola a la derecha?

# %%
H0 = "El nuevo medicamento NO es mayor que 130"
decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "R")
print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, n, "R")
# Out:
# z critico 2.3263478740408408
# z calculado 2.039471845179307
# Se acepta H0: El nuevo medicamento NO es mayor que 130 con nivel de confianza del 99.0 %
# z critico 2.3263478740408408
# z calculado 2.039471845179307
# Valor de p_prueba 0.0207
# Valor de p_value 0.99
# Valuando probabilidades ...
# Se rechaza Ho
# ''

# %% [markdown]
# No hay evidencia estadística suficiente para rechazar $H_0$, por lo que se acepta $H_0$ cola a la derecha a un 99% de confianza.

# %% [markdown]
# # Interpretación del caso
#
# * Del ejercicio 1 del peso de los estudiantes ¿se acepta la $H_0$ a dos colas si es al 95% o al 99%?
#
# * Del ejercicio 2 de la estatura de los estudiantes ¿se acepta la $H_0$ cola a la izquierda al 90% o al 99%?, y ¿porqué?
#
# * Del ejercicio 3 Tiempo promedio de estudio de alumnos ¿se acepta la $H_0$ cola a la izquierda al 90% o al 95%?, y ¿porqué?
#
# * Del ejercicio 4 el nuevo medicamento para la presión, que pasa si se cambia de 130 a 120 el valor de estimación $\mu=120$, al hacer la prueba de hipótesis al 99% de confianza ¿se aceptan o rechazan las $H_0$ a dos colas, cola a la izquiera o cola a la derecha?
#
#
# En las pruebas de hipótesis, se utiliza la distribución $Z$ (distribución normal estándar) cuando se cumplen ciertas condiciones, especialmente cuando la muestra es grande (generalmente se considera que $n > 30$ es lo suficientemente grande).
#
# La distribución $Z$ se utiliza para calcular los valores críticos y los estadísticos de prueba en estas pruebas.
#
# La distribución $Z$ es una distribución normal con una media de 0 y una desviación estándar de 1.
#
# Se utiliza en pruebas de hipótesis cuando la desviación estándar poblacional es conocida (o se estima a partir de la muestra) y la distribución de la variable en estudio es aproximadamente normal.
#
# En el caso de las pruebas de hipótesis de los ejercicios planteados, se utiliza la distribución Z porque:
#
# * Tal vez, el tamaño de la muestra es lo suficientemente grande.
# * La desviación estándar poblacional es conocida o se estima a partir de la muestra. **Se conoce la desviación estándar de la población o se estima**
# La distribución de la variable de estudio se asume que es aproximadamente normal.

# %% [markdown]
# # Bibliografía
#
# * Anderson, D., Sweeney, D., & Williams, T. (2008). Estadística para administración y economía Estadística para administración y economía. 10a. Edición. México, D.F: Cengage Learning Editores,S.A. de C.V.
# * Devore, J. L. (2018). Fundamentos de Probabilidad y Estadística. California Polytechnic State University, San Luis Obispo: CENCAGE.
# * Mendenhall, W., Beaver, R. J., & Beaver, B. M. (2010). Introducción a la probabilidad y estadística. México, D.F.: Cengage Learning Editores, S.A. de C.V.
# * ChatGPT
