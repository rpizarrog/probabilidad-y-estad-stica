# %% [markdown]
# <a href="https://colab.research.google.com/github/rpizarrog/probabilidad-y-estad-stica/blob/master/2024/Caso_20_Distribuci%C3%B3n_uniforme_continua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Distribución uniforme continua
#
# # Objetivo
#
# Calcular probabilidades de variabes aletorias que se comportan bajo a distribución uniforme continua
#
# # Decripción
#
# - Se cargan librerías
# - Se cargan funciones previaemnte preparadas
# - Se definen ejercicios de disrtibucion uniforme continua
# - Se calculan proablida
# - Se visualiza densidad y áreas bajo la curva de probabildiades
# - Se interpreta el caso

# %% [markdown]
# # Fundamento teórico
#
# La distribución uniforme es una distribución de probabilidad que modela la igualdad de posibilidad entre los eventos en un rango determinado. Puede ser discreta o continua, dependiendo del conjunto de valores que puede tomar la variable aleatoria.
#
# La distribución uniforme discreta se utiliza cuando la variable aleatoria solo puede tomar un número finito de valores, y la probabilidad de cada valor es igual. Por ejemplo, si lanzamos un dado justo, cada número del 1 al 6 tiene la misma probabilidad de 1/6 de aparecer.
#
# Por otro lado, la distribución uniforme continua se utiliza cuando la variable aleatoria puede tomar cualquier valor en un intervalo continuo, y la probabilidad de cada valor es igual. Por ejemplo, si elegimos un número al azar entre 0 y 1, cada número en ese intervalo tiene la misma probabilidad de aparecer
#
# La diferencia entre una distribución uniforme discreta y una distribución uniforme continua se encuentra en sus posibles valores.
#
# La distribución uniforme discreta solo puede tomar algunos valores dentro de un intervalo además de que los valores de x's son enteros; en cambio, la distribución uniforme continua puede tomar cualquier valor dentro del intervalo en el que está definida incluyendo enteros y números reales.
#
# En general, las distribuciones uniformes discretas solo pueden tomar valores enteros, mientras que las distribuciones uniformes continuas también pueden tomar valores decimales.
#
# La distribución uniforme continua es una familia de distribuciones de probabilidad para variables aleatorias continuas, tales que para cada miembro de la familia, todos los intervalos de igual longitud en la distribución en su rango son igualmente probables. El dominio está definido por dos parámetros, $a$ y $b$, que son sus valores mínimo y máximo respectivamente.
#
# La distribución o modelo uniforme puede considerarse como proveniente de un proceso de extracción aleatoria .El planteamiento radica en el hecho de que la probabilidad se distribuye uniformemente a lo largo de un intervalo . Así : dada una variable aleatoria continua, $x$ , definida en el intervalo $[a,b]$ de la recta real, se dice que $x$ tiene una distribución uniforme en el intervalo $[a,b]$.
#
#
# ## Función de densidad
#
# $$
# f(x) =
# \begin{cases}
# \frac{1}{b-a} &,\, \text{para }a\leq x \leq b ,\\
# 0&,\, \text{en cualquier otro caso }
# \end{cases}
# $$
#
# La probabilidad únicamente depende del valor de $(x-a)$
#
# En donde:
#
# -   $F(x)$es la función de distribución o función de probabilidad acumulada
#
# -   $x$ es la variable aleatoria uniforme
#
# -   $a$ y $b$ son los valores del intervalo mínimo y máximo respectivamente.
#
#
# La gráfica de esta función, conocida como *curva o función de densidad,* es un **rectángulo**, por ello la distribución uniforme continua se conoce también como *distribución rectangular* y es la más simple de las distribuciones continuas. [@lifeder].
#
#
# ## Función de probabilidad acumulada
#
# Para calcular probabilidades se puede determinar a función de la distribución $F(X)$ o lo que es lo mismo la Función Acumulada de probabilidad de la distribución uniforme con la siguiente fórmula:
#
# $$
# P(x) = F(x) = \begin{cases}0; \text{ para }x \le a \\\frac{x-a}{b-a} \text{ para } a\le x \le b \\1 ; \text{ para }  x >b
# \end{cases}
# $$
#
#
# ## Valor esperado VE
#
# El cálculo del valor esperado y de la varianza de una variable aleatoria continua es análogo al de una variable aleatoria discreta. Sin embargo, como en este caso interviene el cálculo integral la deducción de estas fórmulas queda fuera de los ejercicios de este caso.
#
# $$E(x) = \frac{(a+b)}{2}$$
#
#
# ## Varianza y desviación estándar
#
# $$
# varianza_{(x)} = \sigma^2 = \frac{(b-a)^2}{12}
# $$
#
#
# $$
# \sigma = \sqrt{\sigma^2}
# $$
#
# ## Funciones en Python
#
# En programación Python se utiliza la librería *scipy.stats uniforme* que integra a las siguientes funciones para tratar con variables aleatorias de distribución uniforme continua:
#
# - Para generar números aleatorios: *uniform(loc=a, scale=b-a)* en combinación con *dist_uniforme.rvs(size=n)*
# - Para calcular la densidad: *dist_uniforme.pdf(x)*
# - Para calcular la probabilidad acumulada *dist_uniform.cdf(x)*
# - Función para obtener *x* a partir de una probabilidad en distribución uniforme *uniform.ppf(q, loc=a, scale=(b - a))*

# %% [markdown]
# # Desarrollo
#
# ## Cargar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# %% [markdown]
# ## Cargar funciones

# %%
def f_dens_uniforme(a, b, x):
  if (a <= x) and (x <= b):
    densidad = 1 / (b - a)
  else:
    densidad = 0
  return densidad

def f_visualizar_densidad_uniforme(x, a_min, amplitud, v_str):
  # Graficar la densidad de probabilidad
  if x is None:
    x = uniform.rvs(loc = a_min, scale = amplitud, size=10)
  # Se generan números ants y despues del inervalo para que visualizar
  # la densidad igual a cero de acuerdo con la fórmula
  numeros = np.sort(np.concatenate([[a_min-1, a_min + amplitud + 1, a_min, a_min+amplitud, a_min-0.0001, (a_min + amplitud + 0.0001)], x]))
  # print (numeros)
  pdf = uniform.pdf(x=numeros, loc = a_min, scale = amplitud )

  # print (pdf)
  plt.plot(numeros, pdf, label='Densidad de probabilidad')
  plt.title('Distribución Uniforme Continua; '+v_str)
  plt.xlabel("Valores de x's; variable aleatoria x")
  plt.ylabel('Densidad de probabilidad. Altura del rectángulo')
  plt.legend()
  plt.show()

def f_prob_uniforme(x, a, b):
  if (a <= x) and (x <= b):
    probabilidad = (x - a) / (b - a)
  else:
    probabilidad = 1
  return probabilidad

def f_prob_area_uniforme(a, b, a_min, b_max, v_str):
  n = 1000
  amplitud = (b_max - a_min)
  # Se generan n números aleatorios
  x = uniform.rvs(loc = a_min, scale = amplitud, size=n)
  numeros = np.sort(np.concatenate([[a_min - 1, a_min + amplitud + 1, a_min, a_min + amplitud, a_min-0.0001, (a_min + amplitud + 0.0001)], x]))

  # La densidad de cada valor aletorio
  pdf = uniform.pdf(x=numeros, loc = a_min, scale = amplitud )

  # Se visualizan
  plt.plot(numeros, pdf, label='Densidad de probabilidad')

  # Determinar la probabilidad con funciones python
  probabilidad = uniform.cdf(x = b, loc = a_min, scale = amplitud) - uniform.cdf(x = a, loc = a_min, scale = amplitud)


  # Rellenar área bajo la curva
  # Resaltar el área entre a y b
  plt.fill_between(numeros, pdf, where=(numeros >= a) & (numeros <= b), alpha=0.3, color='red', label=f'Área entre {a} y {b}, {probabilidad*100:.2f}%')

  plt.title('Distribución Uniforme Continua; '+v_str)
  plt.xlabel("Valores de x's; variable aleatoria x")
  plt.ylabel('Densidad de probabilidad. Altura del rectángulo')
  plt.legend(loc='upper right')
  plt.show()

def f_dens_uniforme_VE_desv_std(a, b, a_min, b_max, v_str, VE, desv_std):
  n = 1000
  amplitud = b_max - a_min
  # Se generan n números aleatorios
  x = uniform.rvs(loc = a_min, scale = amplitud, size=n)
  numeros = np.sort(np.concatenate([[a_min-1, a_min + amplitud + 1, a_min, a_min+amplitud, a_min-0.0001, (a_min + amplitud + 0.0001)], x]))

  # La densidad de cada valor aletorio
  pdf = uniform.pdf(x=numeros, loc = a_min, scale = amplitud )

  # Se visualizan
  plt.plot(numeros, pdf, label='Densidad de probabilidad')

  plt.axvline(x=VE, color='red', linestyle='--', label=f'Valor Esperado (VE) = {VE:.2f}')
  plt.axvline(x=VE + desv_std, color='blue', linestyle='--', label=f'Desviación Estándar = {desv_std:.2f}')
  plt.axvline(x=VE - desv_std, color='green', linestyle='--')

  plt.title('Distribución Uniforme Continua; '+v_str)
  plt.xlabel("Valores de x's; variable aleatoria x")
  plt.ylabel('Densidad de probabilidad. Altura del rectángulo')
  plt.legend(loc='upper right')
  plt.show()

# %% [markdown]
# ### Calcular números aleatorios de distribución uniforme
#
# Se calcular valores aleatorios de entre $10$ y $15$ y se visualiza la probabilidad del intervalo $10-15$
#
# $$min = 10$$
# $$amplitud = 5$$
# $$max = min + amplitud \therefore 10 + 5 = 15$$

# %%
a_min = 10
amplitud = 5
b_max = a_min + amplitud
v_str = "Números aleatorios" # Variable que almacena un string
print("Números aleatorios en el rango ", a_min ," - ", b_max)
print ("min + amplitud = maximo; ", a_min, " + ", amplitud, " = ", b_max)
numeros_aleatorios = uniform.rvs(loc = a_min, scale = amplitud, size=10)
print (numeros_aleatorios)

f_visualizar_densidad_uniforme(numeros_aleatorios, a_min, b_max, v_str)
# Out:
# Números aleatorios en el rango  10  -  15
# min + amplitud = maximo;  10  +  5  =  15
# [12.77372503 14.21924729 14.48934973 14.77828532 11.51779487 13.22349931
#  12.76207679 12.83421533 11.82850147 12.55777242]

# %% [markdown]
# ## Ejercicios. Tiempo de vuelo
#
# Considere una variable aleatoria $x$ que representa el tiempo de vuelo de un avión que viaja de Chicago a Nueva York. Suponga que el tiempo de vuelo es cualquier valor en el intervalo de $a=120$ minutos a $b=140# minutos [@anderson_estadistica_2008].
#
# Dado que la variable aleatoria $x$ toma cualquier valor en este intervalo $\text{120}{140}$, $x$ es una variable aleatoria **continua** .
#
# Hay que razonar que se cuenta con datos suficientes como para concluir que la probabilidad de que el tiempo de vuelo esté en cualquier intervalo de $1$ minuto es el mismo que la probabilidad de que el tiempo de vuelo esté en cualquier otro intervalo de $1$ o inclusive menor o mayor siempre y cuando esté dentro del intervalo que va de $120$ a $140$ minutos.
#
# Como cualquier intervalo de $1$ minuto es igual de probable, se dice que la variable aleatoria $x$ tiene una **distribución de probabilidad uniforme** continua [@anderson_estadistica_2008].
#
# Tratándose de una distribución uniforme el área bajo la curva es la parte proporcional del rectángulo.
#
# Se pide:
# - ¿Cuál es el valor de la densidad en el intervalo $120-140$?, para cualquier valor de $x$ en ese intervalo,
# - Visualizar la densidad del intervalo $120-140$,
# - ¿Cuál es la probabilidad de que el avión llegue entre $125$ y $130$ minutos?; $a=125$, $b=130$.
# - ¿Cómo se visualiza el área bajo la curva del intervalo $125-130$,
# - ¿Cuál es el valor esperado $VE$?
# - ¿Cuál es la varianza $\sigma^2$ y la desviación estándar $\sigma$?
# - ¿Qué significado tiene el valor esperado $VE$ y la desviación estándar $\sigma$ del ejercicio del tiempo de vuelo del avión ?

# %% [markdown]
# ### Inicializar variables

# %%
a_min = 120
amplitud = 20
b_max = a_min + amplitud # 140
v_str = "Tiempo de vuelo del avión"
x = uniform.rvs(loc = a_min, scale = amplitud, size=1) # Aleatorio entre a_min y b_min
print ("Variable aleatoria x: ", np.round(x, 2))
altura = 1 / (b_max - a_min) # Es la altura

print (f"Es la altura del área bajo la curva: {altura:.2f}")
print (f"La densidad es lo mismo que la altura: {f_dens_uniforme(a = a_min, b = b_max, x = x):.2f}")
print (f"Densidad con función uniform.pdf() : {float(uniform.pdf(x = x, loc = a_min, scale = amplitud)):.2f}")
# Out:
# Variable aleatoria x:  [134.38]
# Es la altura del área bajo la curva: 0.05
# La densidad es lo mismo que la altura: 0.05
# Densidad con función uniform.pdf() : 0.05

# %% [markdown]
# ### Visualizar la densidad
#
# Mandar llamar la función *f_visualizar_densidad_uniforme()* que visualiza la densidad; se manda llamar ahora sin números aleatorios, estos se generan y se encapsulan en la función misma que permite construir la densidad.
#
# Todo valor de $x$ entre $120$ y $140$ tienen la misma $densidad = altura$.

# %%
f_visualizar_densidad_uniforme(x = None, a_min = a_min, amplitud=amplitud, v_str= v_str)

# %% [markdown]
# ### Probabilidad de tiempo de vuelo entre 125 y 130

# %% [markdown]
# #### Probabilidad con base * altura

# %%
a = 125
b = 130
base = (b - a)  # 5

print (f"Probabilidad = area = base * altura = {base * altura:.2f}\n")
# Out:
# Probabilidad = area = base * altura = 0.25

# %% [markdown]
# #### Probabilidad conforme fórmula acumulada
#
# $$
# P(x) = F(x) = \begin{cases}0; \text{ para }x \le a \\\frac{x_i-a}{b-a} \text{ para } a\le x \le b \\1 ; \text{ para }  x >b
# \end{cases}
# $$
#
# Restar la probabilidad acumulada de $130$ a la probabilidad acumulada de $125$.
#
# $$
# probabilidad = \frac{x_{i}=130-120}{140-120} - \frac{x_{i}=125-120}{140-120} =
# $$
# $$
# probabilidad = \frac{10}{20} - \frac{5}{20} = 0.5 - 0.25 = 0.25
# $$
#
# Se manda llamar la función previamente codificada *f_prob_uniforme()* que recibe los valores de *x1, x2* y *a_min, *b_max*.

# %%
x1 = 125 # a intervalo dentro de intervalo
x2 = 130 # b intervalo debtro de intervalo
print ("Conforme fórmula de F de función acumulada: F(x)")
probabilidad = f_prob_uniforme(x = x2, a = a_min, b = b_max) - f_prob_uniforme(x = x1, a = a_min, b = b_max)
print (f"Probabilidad = {probabilidad * 100:.2f}%")
# Out:
# Conforme fórmula de F de función acumulada: F(x)
# Probabilidad = 25.00%

# %% [markdown]
# #### Conforme a función acumulada de python *uniform.cdf()*
#
# Restando el valor de acumulado de 130 al valor acumulado de 125, se utiliza la función de python *uniform.cdf* de la librerpia *scipy.stats*

# %%
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 25.00%

# %% [markdown]
# #### Visualizar probabilidad
#
# Se visualiza el área bajo la curva de intervalo $\text{125 a 130}$ en relación a todo el área bajo la curva de $\text{120 a 140}$.
#
# Se manda llamar la función *f_cual()?* previamente codificada para representar el área bajo la cura.

# %%
f_prob_area_uniforme(a = a, b = b, a_min = a_min, b_max = b_max, v_str = v_str)

# %% [markdown]
# ### Valor esperado
#
#
# $$
# VE= E(x) = \frac{(a+b)}{2}
# $$
#
# $$
# VE = E(x) = \frac{(120+
# 140)}{2}=130
# $$
#
# Significa el tiempo de vuelo que tarda en promedio el avió en llegar de la ruta de una ciudad a otra.

# %%
VE = (a_min + b_max) / 2
print ("Valor esperado = ", VE, " minutos ")
# Out:
# Valor esperado =  130.0  minutos

# %% [markdown]
# ### Varianza
#
# $$
# varianza_{(x)} = \sigma^2 = \frac{(b-a)^2}{12}
# $$
#
# $$
# varianza_{(x)} = \sigma^2 =
# \frac{(140-120)^2}{12}=33.33
# $$

# %%
varianza = ((b_max - a_min) ** 2) / 12
print (f"Varianza = {varianza:.4f}")
# Out:
# Varianza = 33.3333

# %% [markdown]
# Desviación estándar
#
# $$
# \sigma = \sqrt{\sigma^2}
# $$
#
# $$
# \sigma = \sqrt{\sigma^2} = \sqrt{33.33} =
# 5.77
# $$

# %%
desv_std = np.sqrt(varianza)
print (f"Desviación estándar =  {desv_std:.2f} minutos ")
# Out:
# Desviación estándar =  5.77 minutos

# %% [markdown]
# ### Densidad con VE y desviación estándar
#
# Se manda llamar *f_prob_area_uniforme_VE_desv_std()*

# %%
f_dens_uniforme_VE_desv_std(a = a, b = b, a_min = a_min, b_max = b_max, v_str = v_str, VE = VE, desv_std = desv_std)

# %% [markdown]
# ### ¿Probabilidad de 128 a 134?
#
# $$
# F(128 \le x \le 134)
# $$
# ¿Cuál es la probabilidad de que el avión llegue entre $128$ y $134$ minutos?

# %%
x1 = 128
x2 = 136
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 40.00%

# %% [markdown]
# ### ¿Probabilidad de 122 a 138?
#
# $$
# F(122 \le x \le 138)
# $$
# ¿Cuál es la probabilidad de que el avión llegue entre $122$ y $138$ minutos?

# %%
x1 = 122
x2 = 138
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 80.00%

# %% [markdown]
# ### Probabilidad menor o igual a 124
#
# $$
# F(x \le 124)
# $$
# ¿Cuál es la probabilidad de que el avión llegue menor a 124 minutos?

# %%
x1 = 120
x2 = 124
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 20.00%

# %% [markdown]
# ### Probabilidad mayor o igual a 137.5
#
# $$
# F(x \ge 137.5)
# $$
# ¿Cuál es la probabilidad de que el avión llegue más o igual de 137.5 minutos?

# %%
x1 = 137.5
x2 = 140
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 12.50%

# %% [markdown]
# ## Licitaciones de fabricación de circuitos impresos
#
# Al estudiar licitaciones de embarque, una empresa dedicada a la fabricación de circuitos impresos, encuentra que los contratos nacionales tienen licitaciones distribuidas uniformemente entre $20$ y $25$ unidades (en miles de dólares).(Aqueronte 2009)
#
# - Valor mínimo es $\text{a_min=20}$
# - Valor máximo es de $\text{b_max=25}$
#
# Se pide lo siguiente:
#
# - Valor de la densidad
# - Visualizar la densidad
# - Calcular y visualizar probabilidades:
#   - ¿Cuál es la probabilidad de que la licitación esté entre 22 y 24 (mil dólares), $F(22 \le x\le 24)$?
#   - ¿Cuál es la probabilidad de que sea inferior o igual a 22 (mil dólares), $F(x\le 22)$?
#   - ¿Cuál es la probabilidad de que rebase o sea igual a los 24 (mil dólares), $F(x\ge 24)$?
#   - ¿Cuál es el valor esperado $VE$?
#   - ¿Cuál es el valor de la varianza?
#   - ¿Cuál es la desviación estándar $\sigma$?
#   - Qué significado tiene el $VE$ y la desviación estandar $\sigma$ en el ejercicio de licitaciones?

# %% [markdown]
# ### Inicializar variables

# %%
a_min = 20
amplitud = 5
b_max = a_min + amplitud
v_str = "Licitaciones"

# %% [markdown]
# ### La densidad

# %%
# Generando una variable aleatoria
x = uniform.rvs(loc = a_min, scale = amplitud, size=1) # Aleatorio entre a_min y b_min
print ("Variable aleatoria x: ", np.round(x, 2))

altura = 1 / (b_max - a_min) # Es la altura
print (f"Es la altura del área bajo la curva: {altura:.2f}")
print (f"La densidad es lo mismo que la altura: {f_dens_uniforme(a = a_min, b = b_max, x = x):.2f}")
print (f"Densidad con función uniform.pdf() : {float(uniform.pdf(x = x, loc = a_min, scale = amplitud)):.2f}")

f_visualizar_densidad_uniforme(x, a_min, amplitud, v_str)
# Out:
# Variable aleatoria x:  [20.57]
# Es la altura del área bajo la curva: 0.20
# La densidad es lo mismo que la altura: 0.20
# Densidad con función uniform.pdf() : 0.20

# %% [markdown]
# ### Probabilidades
#
# #### ¿Cuál es la probabilidad de que la licitación esté entre 22 y 24 (mil dólares),  F(22≤x≤24) ?

# %%
x1 = 22
x2 = 24
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 40.00%

# %% [markdown]
# #### ¿Cuál es la probabilidad de que sea inferior o igual a 22 (mil dólares),  F(x≤22) ?

# %%
x1 = 20
x2 = 22
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 40.00%

# %% [markdown]
# #### ¿Cuál es la probabilidad de que rebase o sea igual a los 24 (mil dólares),  F(x≥24) ?

# %%
x1 = 24
x2 = 25
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 20.00%

# %% [markdown]
# ### Valor esperado

# %%
VE = (a_min + b_max) / 2
print ("Valor esperado = ", VE, " minutos ")
# Out:
# Valor esperado =  22.5  minutos

# %% [markdown]
# ### Varianza

# %%
varianza = ((b_max - a_min) ** 2) / 12
print (f"Varianza = {varianza:.4f}")
# Out:
# Varianza = 2.0833

# %% [markdown]
# ### Desviacion estándar

# %%
desv_std = np.sqrt(varianza)
print (f"Desviación estándar =  {desv_std:.2f} minutos ")
# Out:
# Desviación estándar =  1.44 minutos

# %% [markdown]
# ### Visualizar densidad con VE y desviación estándar

# %%
f_dens_uniforme_VE_desv_std(a = a, b = b, a_min = a_min, b_max = b_max, v_str = v_str, VE = VE, desv_std = desv_std)

# %% [markdown]
# ## Taxi en Durango
#
# En la zona centro de la ciudad de Durango, México el tiempo de espera para tomar un taxi es de $0$ a $15$ minutos.
#
# - Valor mínimo es $\text{a_min=0}$
# - Valor máximo es de $\text{b_max=15}$
#
# Se pide lo siguiente:
#
# - Valor de la densidad
# - Visualizar la densidad
# - Calcular y visualizar probabilidades:
#   - ¿Cuál es la probabilidad de el taxi llegue entre 5 y 10 minutos, $F(5 \le x \le10)$?
#   - ¿Cuál es la probabilidad de el taxi llegue en menos de 5 minutos $F(x\le5)$?
#   - ¿Cuál es la probabilidad de que rebase o sea igual a los 12 minutos, $F(x \ge12)$?
#   - ¿Cuál es el valor esperado $VE$?
#   - ¿Cuál es el valor de la varianza?
#   - ¿Cuál es la desviación estándar $\sigma$?
#   - Qué significado tiene el $VE$ y la desviación estandar $\sigma$ en el ejercicio taxi en Durango?

# %% [markdown]
# ### Inicializar variables

# %%
a_min = 0
amplitud = 15
b_max = a_min + amplitud
v_str = "Taxi en Durango"

# %% [markdown]
# ### La densidad

# %%
# Generando una variable aleatoria
x = uniform.rvs(loc = a_min, scale = amplitud, size=1) # Aleatorio entre a_min y b_min
print ("Variable aleatoria x: ", np.round(x, 2))

altura = 1 / (b_max - a_min) # Es la altura
print (f"Es la altura del área bajo la curva: {altura:.2f}")
print (f"La densidad es lo mismo que la altura: {f_dens_uniforme(a = a_min, b = b_max, x = x):.2f}")
print (f"Densidad con función uniform.pdf() : {float(uniform.pdf(x = x, loc = a_min, scale = amplitud)):.2f}")

f_visualizar_densidad_uniforme(x, a_min, amplitud, v_str)
# Out:
# Variable aleatoria x:  [5.94]
# Es la altura del área bajo la curva: 0.07
# La densidad es lo mismo que la altura: 0.07
# Densidad con función uniform.pdf() : 0.07

# %% [markdown]
# ## Tiempo de llegada de pedido de un pizza en Durango
#
# En la ciudad de Durago, el tiempo de llegada de un pedido de pizza puede andar entre los 30 y 50 minutos
#
# - Valor mínimo es $\text{a_min=30}$
# - Valor máximo es de $\text{b_max=50}$
#
# Se pide lo siguiente:
#
# - Valor de la densidad
# - Visualizar la densidad
# - Calcular y visualizar probabilidades:
#   - ¿Cuál es la probabilidad de que la pizza llegue entre $34$ y $38$ minutos,  $F(34≤x≤38)$ ?
#   - ¿Cuál es la probabilidad de que llegue en menos de $35$ minutos  $F(x≤35)$ ?
#   - ¿Cuál es la probabilidad de que rebase o sea igual a los $46$ minutos,  $F(x≥46$) ?
#   - ¿Cuál es el valor esperado  VE ?
#   - ¿Cuál es el valor de la varianza?
#   - ¿Cuál es la desviación estándar  σ ?
#   - Qué significado tiene el  VE  y la desviación estandar  σ  en el ejercicio de pedido de pizza en Durango?
#   - ¿Qué sucedería si los tiempos de entrega se modifican y están entre $15$ y $40$ minutos la entrega de la pizza?, ¿Cuál es la probabilidad de entrega esté entre $24$ y $28$ minutos., $F(24 \le x \le 28)$

# %% [markdown]
# ### Inicializar variables

# %%
a_min = 30
amplitud = 20
b_max = a_min + amplitud
v_str = "Pizza en Durango"

# %% [markdown]
# ### Densidad

# %%
# Generando una variable aleatoria
x = uniform.rvs(loc = a_min, scale = amplitud, size=1) # Aleatorio entre a_min y b_min
print ("Variable aleatoria x: ", np.round(x, 2))

altura = 1 / (b_max - a_min) # Es la altura
print (f"Es la altura del área bajo la curva: {altura:.2f}")
print (f"La densidad es lo mismo que la altura: {f_dens_uniforme(a = a_min, b = b_max, x = x):.2f}")
print (f"Densidad con función uniform.pdf() : {float(uniform.pdf(x = x, loc = a_min, scale = amplitud)):.2f}")

f_visualizar_densidad_uniforme(x, a_min, amplitud, v_str)
# Out:
# Variable aleatoria x:  [33.39]
# Es la altura del área bajo la curva: 0.05
# La densidad es lo mismo que la altura: 0.05
# Densidad con función uniform.pdf() : 0.05

# %% [markdown]
# ### Probabilidades
#
# #### ¿Cuál es la probabilidad de que la pizza llegue entre 34 y 38 minutos, F(34≤x≤38) ?

# %%
x1 = 34
x2 = 38
print ("Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()")
probabilidad = uniform.cdf(x = x2, loc = a_min, scale = amplitud) - uniform.cdf(x = x1, loc = a_min, scale = amplitud)
print (f"Con función uniform.cdf() {probabilidad * 100:.2f}%")

f_prob_area_uniforme(a = x1, b = x2, a_min = a_min, b_max = b_max, v_str = v_str)
# Out:
# Conforme función de probabilidad acumulada de Pyhton; uniform.cdf()
# Con función uniform.cdf() 20.00%

# %% [markdown]
# ## Entrega de Pizza entre 15 y 40 minutos
#
# ¿Qué sucedería si los tiempos de entrega se modifican y están entre $15$ y $40$ minutos la entrega de la pizza?, ¿Cuál es la probabilidad de entrega esté entre $20$ y $32$ minutos., $F(20 \le x \le 32)$

# %%
a_min = 15
b_max = 45
amplitud = b_max - a_min
v_str = "Entrega de Pizza 15-45"

# %%
a = 20
b = 32
f_prob_area_uniforme(a = a, b = b, a_min = a_min, b_max = b_max, v_str = v_str)

# %% [markdown]
# ## Compañía de luz
#
# Una compañía que brinda servicio eléctrico provee niveles de voltajes uniformemente distribuidos, entre $123.0$ V y $125.0$ V. Esto significa que en la toma doméstica es posible obtener cualquier valor de voltaje que pertenezca a dicho intervalo.
#
# $$
# \text{a_min = 123}
# $$
# $$
# \text{b_max = 125}
# $$
#
# Se pide:
#
# - ¿Cuál es el valor de la densidad
# Visualizar la densidad
# - ¿Cúal es el valor esperado y la desviación estádnar y su significado?
# - Visualizar densidad con el valor esperado y la desvición estándar
# - ¿Cuál es la probabilidad de que se tenga un consumo de energía eléctrica por debajo de $123.5$ Volts.?; $a = 123; b = 123.5$
#
# $$
# F(x \le 123.5) = \frac{123.5 - 123}{125 - 123} = \frac{.5}{2} = 0.25 ≈ 25\%
# $$

# %% [markdown]
# ### Inicializando variables

# %%
a_min = 123 # Volts
b_max = 125 # Volts
amplitud = b_max - a_min
v_str = "Consumo de energía. Cía de luz"

# %% [markdown]
# ### Densidad

# %%
# Generando una variable aleatoria
x = uniform.rvs(loc = a_min, scale = amplitud, size=1) # Aleatorio entre a_min y b_min
print ("Variable aleatoria x: ", np.round(x, 2))

altura = 1 / (b_max - a_min) # Es la altura
print (f"Es la altura del área bajo la curva: {altura:.2f}")
print (f"La densidad es lo mismo que la altura: {f_dens_uniforme(a = a_min, b = b_max, x = x):.2f}")
print (f"Densidad con función uniform.pdf() : {float(uniform.pdf(x = x, loc = a_min, scale = amplitud)):.2f}")

f_visualizar_densidad_uniforme(x, a_min, amplitud, v_str)
# Out:
# Variable aleatoria x:  [124.93]
# Es la altura del área bajo la curva: 0.50
# La densidad es lo mismo que la altura: 0.50
# Densidad con función uniform.pdf() : 0.50

# %% [markdown]
# ### Valor esperado, varianza y desviación estádnar
#
# Se calcula el valor esperado $VE$, la varianza $\sigma^2$ y la desviación estándar $\signa$ y se visualiza, todo en la misma celda.

# %%
#Valor esperado
VE = (a_min + b_max) / 2
print ("Valor esperado = ", VE, " volts ")

# varianza
varianza = ((b_max - a_min) ** 2) / 12
print (f"Varianza = {varianza:.4f}")

# Desviación std
desv_std = np.sqrt(varianza)
print (f"Desviación estándar =  {desv_std:.2f} volts ")

# Visualizar
f_dens_uniforme_VE_desv_std(a = a, b = b, a_min = a_min, b_max = b_max, v_str = v_str, VE = VE, desv_std = desv_std)
# Out:
# Valor esperado =  124.0  volts
# Varianza = 0.3333
# Desviación estándar =  0.58 volts

# %% [markdown]
# ### Probabilidad
#
# #### ¿Cuál es la probabilidad de que se tenga un consumo de energía eléctrica por debajo de  123.5  Volts.?

# %%
a = 123
b = 123.5

f_prob_area_uniforme(a = a, b = b, a_min = a_min, b_max = b_max, v_str = v_str)

# %% [markdown]
# ## Ejercicio de llegada al trabajo
#
# El tiempo en minutos que tarda una persona para ir de su casa al trabajo oscila de forma uniforme entre $20$ y $30$.
#
# $$
# \text{a_min = 20}
# $$
# $$
# \text{b_max = 30}
# $$
# Si debe llegar al trabajo a las $8:00$ de la mañana,
#
# Demuestre en Python ¿a qué hora debe salir de su casa para tener una probabilidad de $0.90$ o del $90%$ de no llegar tarde?
#
# Si $x$ denota el tiempo en ir de casa al trabajo (en minutos), su distribución es uniforme en el intervalo $U(20 - 30)$.
#
# Se busca el valor de a tal que $P(x≤a)=0.90$ o $F(x \le a) = 0.90$.
#
# $$
# F(x≤a) = \frac{a−20}{30−20}=0.90\therefore \frac{a−20}{10}=0.90∴
# $$
# $$
# a - 20 = 0.90 * 10 \therefore a = 9 +20
# $$
#
# $$
# a = 29
# $$
#
# Por tanto, debe salir de casa a las $7:31$ para tener la probabilidad del $90\%$ de llegar a las $8:00$ a su trabajo.

# %% [markdown]
# ### La función inversa de la probabilidad uniforme
#
# Se utiliza la función *uniform.ppf(q, loc=a, scale=(b - a))*

# %%
x = uniform.ppf(q= 0.90, loc=a_min, scale=(b_max - a_min))
print ("Valor de x es: ", x)
print ("Representa los minutos antes de las 8:00 que debe salir de su casa")
# Out:
# Valor de x es:  24.5
# repreenta los minutos antes de las 8:00 que debe salir de su casa

# %% [markdown]
# El valor de $29$ representa los minutos antes de las $8:00$ que debe salir de su casa, o sea a las $8:00$ menos $29$ minutos igual a $7:31$

# %%
a_min = 20
b_max = 30
amplitud = b_max - a_min
v_str = "Tiempo de llegada al trabajo de una persona"

a = 20
b = 29  # ¿De dónde obtener el 29 ?

f_prob_area_uniforme(a = a, b = b, a_min = a_min, b_max = b_max, v_str = v_str)

# %% [markdown]
# # Interpretación del caso
#
# Contestar las preguntas de cada ejercicio
#
# - Ejercicio de tiempo de vuelo del avión Chicago New York
# - Ejercicio de licitaciones
# - Ejercicio de taxi en Durango
# - Ejercicio de pizza en Durango
# - Ejercicio de consumo de energía eléctrica
# - Ejercicio de llegada al trabajo
#
# # Bibliografía
#
# - Anderson, David R., Dennis J. Sweeney, and Thomas A. Williams. 2008. Estadística Para Administración y Economía. 10th ed. Australia • Brasil • Corea • España • Estados Unidos • Japón • México • Reino Unido • Singapur: Cengage Learning,.
#
# - Aqueronte. 2009. “R: Distribución Uniforme.” 2009. http://unbarquero.blogspot.com/2009/05/r-distribucion-uniforme.html.
#
# - lifeder. “Distribución uniforme continua: características, ejemplos, aplicaciones”. https://www.lifeder.com/distribucion-uniforme-continua/.
#
# - https://rpubs.com/rpizarro/1045199
