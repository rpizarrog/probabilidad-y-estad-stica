# %% [markdown]
# <a href="https://colab.research.google.com/github/rpizarrog/probabilidad-y-estad-stica/blob/master/2024/Caso_30_Prueba_de_hip%C3%B3tesis_de_la_media_poblacional_com_distribuci%C3%B3n_t_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Objetivo
#
# Realizar prueba de hipóteis de la media pobacional usando la distribución *t student*.

# %% [markdown]
# # Descripción
#
# # Descripción
#
# Este caso 30 tiene similares aspecos que el caso 29, solo que en este caso se utiliza para todo tipo de prueba de hipótesis de la media poblacional usando la distribución *t* student.
#
# - Cargar librerías.
# - Cargar funciones para este caso.
# - Identificar y visualizar los valores críticos de t con ciertos niveles de confianza.
# - Identificar y visualizar la probabilidad de aceptación de hipótesos con *p_prueba* comparado contra la probabilidad *p_value* para aceptar  o rechazar $H_0$.
# - Identificar datos iniciales de ejercicios para prueba de hipótesis a dos colas, hipótesis nula alternativa.
# - Identificar datos inicales de ejercicios para prueba de hipótesis cola a la izquierda, hipótesis nula alternativa.
# - Identificar datos inicales de ejercicios para prueba de hipótesis cola a la derecha, hipótesis nula alternativa.
# - Interpretación de ejercicios y del caso.
#
# # Fundamento teórico
#
# La prueba de hipótesis es un método estadístico que se utiliza para tomar decisiones sobre las características y parámetros de una población, basándose en la información o estadísticos obtenidos de una muestra.
#
# ¿Existe relación de prueba de hipótesis con intervalos de confianza?
#
# La relación que existe entre los intervalos de confianza y la prueba de hipótesis es tal, que precisamente los valores de prueba deben estar en la zona de intervalo de confianza determinado y permite con ello hacer contraste de valores de prueba para aceptar o rechazar alguna hipótesis.
#
# La inferencia estadística basada en lograr la resolver la naturaleza de afirmaciones contradictorias está relacionada con la prueba de hipótesis.
#
# Estas afirmaciones contradictorias, tiene que ver con el concepto de declaración de hipótesis. A lo que da lugar el concepto de hipótesis estadística que lo define con claridad.
#
# Una hipótesis estadística o simplemente una hipótesis es una afirmación o aseveración sobre el valor de un solo parámetro (característica de una población o característica de una distribución de probabilidad)” (Devore, 2018, pág. 253).
#
# Una hipótesis estadística es una aseveración o conjetura con respecto a una o más poblaciones” (Mendenhall, Beaver, & Beaver, 2010, pág. 321).
#
# Un contraste o prueba de hipótesis, consiste en plantear dos hipótesis, la hipótesis nula $(H_0)$ y la hipótesis alternativa $(H_1)$, y luego recopilar evidencia en forma de datos para determinar si hay suficiente evidencia para rechazar la hipótesis nula en favor de la hipótesis alternativa.

# %% [markdown]
# ## Fórmula para calcular el valor de z para contraste o prueba contra t críticos
#
# Para calcular  t  a contrastar se utiliza la fórmula siguiente:
# $$
# t = \frac{{\bar{x} - \mu}}{{S / \sqrt{n}}}
# $$
#
# t es el valor de prueba a contrastar contra valores críticos de t.
#
# * $\bar{x}$ es la media de la muestra.
# * μ  es la media estimada de la población. Es el valor de comparación.
# * S  es la desviación estándar de la muestra.
# * n  es el tamaño de la muestra.

# %% [markdown]
# ## Proceso para prueba de hipótesis
#
# El proceso para realizar prueba de hipótesis usando distribución *t student* es similar al del del caso 29, aquí nuevamente se citan pasos a realizar:
#
# 1. Formulación de hipótesis: Se establecen la hipótesis nula $(H_0)$, que generalmente afirma que no hay efecto o diferencia, y la hipótesis alternativa $(H_1)$, que afirma lo contrario.
#
# 2. Selección de nivel de significancia: Se elige un nivel de significancia (α) que representa la probabilidad de cometer un error de tipo I al rechazar la hipótesis nula cuando es verdadera. Un valor común para alpha es $α$ es $0.05$.
#
#   En casos anteriores, al identificar intervalos de confianza se requería el nivel de confianza para determinar el valor de alfa.
#
# 3. Selección de prueba estadística: Se selecciona una prueba estadística apropiada basada en el tipo de datos y la naturaleza de la hipótesis.
#
# 4. Cálculo del estadístico de prueba: Se calcula el estadístico de prueba a partir de los datos de la muestra.
#
# 5. Decisión: Se compara el valor del estadístico de prueba con un valor crítico basado en la distribución de probabilidad bajo la hipótesis nula, o se calcula un valor $p$ que representa la probabilidad de obtener un estadístico de prueba al menos tan extremo como el observado si la hipótesis nula es verdadera.
#
# 6. Conclusión: Si el valor $p$ es menor que α, se rechaza la hipótesis nula en favor de la hipótesis alternativa. De lo contrario, no se puede rechazar la hipótesis nula.

# %% [markdown]
# ## Tipos de hipótesis
#
# En estadística se puede declarar tres tipos de hipótesis:
#
# * hipótesis a dos colas, cuando el valor de significancia de *alpha* $α$ se reparte a ambos lados de la curva y conforme a la probabilidad;
#
# * cola a la izquierda cuando toda la probabilidad está del lado izquierdo y el valor del alpha $α$ es igual al complemento del valor de la confiabilidad.
#
# * cola a la derecha cuando toda la probabilidad está del lado derecho y el valor del alpha $α$ es igual al complemento del valor de la confiabilidad.
#
# De acuerdo la prueba de hipótesis se debe comparar un parámetro estimado de la población contra un valor crítico calculado.
#
# La decisión de aceptar la $H_0$ dependerá de la condición de comparación.
#
# |                 | Dos colas        | Cola a la izquierda | Cola a la derecha |
# |-----------------|------------------|----------------------|-------------------|
# | Acepta          | $H_0$: parámetro=valor | $H_0$: parámetro≥ valor | $H_0$: parámetro≤ valor |
# | Rechaza         | $H_a$: parámetro≠valor | $H_0$: parámetro< valor | $H_0$: parámetro> valor |
#
# Convirtiendo esta tabla a una declaración de una hipótesis en donde se busca indagar una media poblacional por ejemplo $μ$ comparada contra un valor de 68 a dos colas, cola izquierda o cola a la derecha.
#
# El operador de igualdad que define si es a dos colas, cola izquierda o cola derecha es el signo de igualdad:
# * '=': es a dos colas,. La expresión de la hipótesis nula $H_0$ sería *"NO es diferente a*".
# * '≥':   es cola a la izquierda o cola inferior. La expresión de la hipótesis nula $H_0$ sería *"NO es menor a*".
# * '≤':  es cola a la derecha o cola superior. La expresión de la hipótesis nula $H_0$ sería *"NO es mayor a*".
#
# |                 | Dos colas        | Cola a la izquierda | Cola a la derecha |
# |-----------------|------------------|----------------------|-------------------|
# | Acepta          | $H_0$: $\mu$=68 | $H_0$: $\mu$ ≥ 68 | $H_0$: $\mu$ ≤ 68 |
# | Rechaza         | $H_a$: $\mu$≠68 | $H_a$: $\mu$< 68 | $H_a$: $\mu$ > valor |
#
#
# ### Prueba de hipótesis contrastando t contra t críticos
#
# En la hipótesis de dos colas significa que se va a aceptar la hipótesis nula $H_0$ siempre y cuando el valor de $t$ calculado se encuentre entre dos valores críticos que son determinados a partir del valor del alfa divido entre dos. $∝⁄2$.
#
# En la hipótesis cola a la izquierda significa que se va a aceptar la hipótesis nula $H_0$ siempre y cuando el valor de $t$ calculado se encuentre por encima del valor crítico a la izquierda que es determinado a partir del valor del alfa $∝$.
#
# En la hipótesis cola a la derecha significa que se va a aceptar la hipótesis nula $H_0$ siempre y cuando el valor de $t$ calculado se encuentre por debajo del valor crítico a la derecha que es determinado a partir del valor del alfa $∝$.
#
# ### Prueba de hipótesis contrastando el valor de *p prueba*
#
# En una prueba de hipótesis, el valor $p$ (*p-value* en inglés) es la probabilidad de obtener un resultado igual al observado o más extremo, bajo la suposición de que la hipótesis nula es verdadera. En otras palabras, el valor $p$ es una medida de la evidencia en contra de la hipótesis nula.
#
# Un valor $p$ pequeño sugiere que la evidencia en contra de la hipótesis nula es fuerte, lo que lleva a rechazar la hipótesis nula en favor de la hipótesis alternativa. Por otro lado, un valor $p$ grande sugiere que la evidencia en contra de la hipótesis nula es débil, lo que lleva a no rechazar la hipótesis nula.
#
# El valor estadístico de *p.valor* se adopta para consolidar la decisión de aceptar o rechazar la hipótesis nula $H_0$. El *p_valor* o *p_value* se calcula en términos de una probabilidad como respaldo a la decisión tomada.
#
# El significado del estadístico *p_valor* es la probabilidad de aceptación o rechazo de la hipótesis nula $H_0$.
#
# Por ejemplo si una probabilidad *p de prueba* es menor que $0.05$ o *p_value* u otro valor de significancia hay que rechazar la hipótesis nula $H_0$, de lo contrario aceptar la $H_0$.
#
# Toda vez que se determine el valor estadístico de *p_prueba*, este se debe comparar contra un nivel de significancia establecido que comúmente  puede ser 0.05 (*p_value*) pero puede ser diferente.
#
# Entonces el algoritmo para aceptar o rechazar $H_0$ a dos colas con *p_value* sería de la siguiente manera:
#
#
# A un nivel de confianza del 95%
#
# $$
# \text{p_prueba = 0.40 y p.value = 0.05}
# $$
#
# $$
# \text{if (p_prueba < p.value)  Se rechaza H0}
# \\ \text{de lo contrario} \\
# \text{if (p_prueba ≥ p.value) Se acepta H0}
# $$
#
# $$
# \text{if (0.40 < 0.05)  Se rechaza H0}
# \\ \text{de lo contrario} \\
# \text{if (0.40 < 0.05) Se acepta H0}
# $$
#
# **Nota importante**:
#
# En la hipótesis a dos colas el valor de $p$ de prueba (*p_prueba*) que es la probabilidad calculalada con respecto a $t$, a ciertos grados de libertdad $gl$  se multiplica dos veces esa probabilidad (por ser a dos colas) para se contrastado contra el *p_value*.
#
# En la hipótesis de cola izquierda o derecha el valor de *p_prueba* es el resultado de la probabilidad con respecto a $t$ a ciertos grados de libertad $gl$ directamente contrastado contra *p_value*.

# %% [markdown]
# # Desarrollo
#
# Inicialmente, se cargan librerías y funciones
#
# Se visualizan los contrastes de los valores de t calculados contra los valores críticos de t extraídos a partir del nivel de confianza.
#
# Hay que hacer mención que los valores críticos de t son extraídos a ñartir de la distribución *t student* a cieros niveles de confianza y ciertos grados de libertdad.
#
# Luego, se presentan diversos ejercicios de pruebas de hipótesis, calculando $t$  y contrastando contra los valor crítico de $t$.
#
# Posteriormente, con el contraste a través de *p.value* se confirma la decisón de la prueba de hipótesis realizada con los valores críticos.
#
# Finalmente se interpretan los resultados.

# %% [markdown]
# ## Cargar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t
from scipy import stats

# %% [markdown]
# ## Cargar funciones
#
# Las funciones que se vargan para la solución de ejercicios son similares a las del caso 29, solo que usando la distribución *t student*.

# %%
# Función que visualiza valores críticos de t a dos colas
def f_aceptar_rechazar_Ho_dos_colas(valor_contraste, confianza, gl, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución t student
    y = t.pdf(x, df=gl)

    alfa = 1 - confianza
    # Definir los valores críticos para un nivel de significancia del 5%
    t_critico_izquierda = t.ppf(alfa / 2, df=gl)
    t_critico_derecha = t.ppf(1 - alfa / 2, df=gl)

    # Valor de t calculado
    t_calculado = valor_contraste

    # Visualización en los ejes proporcionados
    ax.plot(x, y, 'b-', label='Distribución t Student'+"; gl="+str(gl))
    ax.fill_between(x, 0, y, where=(x <= t_critico_izquierda), color='red', alpha=0.5, label='Área de Rechazo (izquierda)')
    ax.fill_between(x, 0, y, where=(x >= t_critico_derecha), color='red', alpha=0.5, label='Área de Rechazo (derecha)')
    ax.axvline(t_critico_izquierda, color='red', linestyle='--', label=f'Valor Crítico (izquierda): {t_critico_izquierda:.4f}')
    ax.axvline(t_critico_derecha, color='red', linestyle='--', label=f'Valor Crítico (derecha): {t_critico_derecha:.4f}')
    ax.axvline(t_calculado, color='green', linestyle='--', label=f'Valor Calculado: {t_calculado:.4f}')
    ax.set_xlabel('t')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title(f'Prueba de Hipótesis. (Dos Colas) Confianza: {confianza*100}%')
    ax.legend()
    ax.grid(False)


# Función que visualiza la probabilidad con p_prueba en relación a p_value
#  a dos colas
def f_aceptar_rechazar_Ho_dos_colas_p_value(valor_contraste, confianza, gl, ax):
  # Definir valores para el eje x
  x = np.linspace(-3, 3, 1000)

  # Calcular la densidad de probabilidad de la distribución t student
  y = t.pdf(x, df=gl)

  alfa = 1 - confianza
  # Definir los valores críticos para un nivel de significancia del 5%
  t_critico_izquierda = t.ppf(alfa / 2, df=gl)
  t_critico_derecha = t.ppf(1 - alfa / 2, df=gl)

  # Valor de t calculado, por el momento es un valor arbitrario solo para explicación
  t_calculado_izq = -(abs(valor_contraste))
  t_calculado_der = abs(valor_contraste)

  # Calcular el valor p para una prueba de dos colas
  p_prueba = 2 * (1 - t.cdf(abs(valor_contraste), df=gl))

  # Visualización en los ejes proporcionados
  ax.plot(x, y, 'b-', label='Distribución t Student')
  ax.fill_between(x, 0, y, where=(x <= t_critico_izquierda), color='red', alpha=0.5, label='Área de Rechazo (izquierda)')
  ax.fill_between(x, 0, y, where=(x >= t_critico_derecha), color='red', alpha=0.5, label='Área de Rechazo (derecha)')
  ax.fill_between(x, 0, y, where=((x <= t_calculado_izq) | (x >= t_calculado_der)), color='green', alpha=0.3, label='Región de Aceptación')
  ax.axvline(t_critico_izquierda, color='red', linestyle='--', label=f'Valor Crítico (izquierda): {t_critico_izquierda:.4f}')
  ax.axvline(t_critico_derecha, color='red', linestyle='--', label=f'Valor Crítico (derecha): {t_critico_derecha:.4f}')
  ax.axvline(t_calculado_izq, color='green', linestyle='--', label=f'Valor t Calculado (izquierda): {t_calculado_izq:.4f}')
  ax.axvline(t_calculado_der, color='green', linestyle='--', label=f'Valor t Calculado (derecha): {t_calculado_der:.4f}')
  ax.set_xlabel('t')
  ax.set_ylabel('Densidad de probabilidad')
  ax.set_title('Prueba de Hipótesis. (Dos Colas)')
  ax.legend()
  ax.grid(False)

# Función que visualiza valor crítico de t cola a la izquierda
def f_aceptar_rechazar_Ho_cola_izquierda(valor_contraste, confianza, gl, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = t.pdf(x, df = gl)

    alfa = 1 - confianza
    # Definir los valores críticos para un nivel de significancia del 10% 5% 1%
    t_critico_izquierda = t.ppf(alfa, df = gl)

    # Valor de t calculado, por el momento es un valor arbitrario solo para explicación
    t_calculado = valor_contraste

    # Visualización en los ejes proporcionados
    ax.plot(x, y, 'b-', label='Distribución t Student')
    ax.fill_between(x, 0, y, where=(x <= t_critico_izquierda), color='red', alpha=0.5, label='Área de Rechazo (izquierda)')

    ax.axvline(t_critico_izquierda, color='red', linestyle='--', label=f'Valor Crítico (izquierda): {t_critico_izquierda:.4f}')
    ax.axvline(t_calculado, color='green', linestyle='--', label=f'Valor Calculado: {t_calculado:.4f}')
    ax.set_xlabel('t')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (Cola Izquierda)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

# Esta función visualiza las probabilidad p_value y p_prueba a distintos niveles de confoanza
# Cola a la izquierda
def f_aceptar_rechazar_Ho_cola_izquierda_p_value(valor_contraste, confianza, gl, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = t.pdf(x, df= gl)

    alfa = 1 - confianza
    # Definir las áreas para un nivel de significancia del 10% 5% 1% a 10 gl
    t_critico_izquierda = t.ppf(alfa, df= gl)
   # t_critico_derecha = t.ppf(1 - alfa / 2, df = gl)

    # Valor de t calculado, por el momento es un valor arbitrario solo para explicación
    t_calculado_izq = valor_contraste
    #t_calculado_der = abs(valor_contraste)

    p_value = np.round(alfa, 4)

    p_prueba = np.round(stats.t.cdf(t_calculado_izq, df=gl), 4)

    ax.plot(x, y, 'b-', label='Distribución t Student'+'; gl='+str(gl))
    ax.fill_between(x, 0, y, where=(x <= t_critico_izquierda), color='red', alpha=0.5, label=f'p_value (izq):{p_value:.4f}')
    #ax.fill_between(x, 0, y, where=(x >= t_critico_derecha), color='red', alpha=0.5, label=f'p_value (der):{(p_value):.4f}; dos colas={p_value}')
    ax.fill_between(x, 0, y, where=(x <= t_calculado_izq), color='green', alpha=0.3, label=f'p_prueba (izq):{p_prueba:.4f}')
    #ax.fill_between(x, 0, y, where=(x >= t_calculado_der), color='green', alpha=0.3, label=f'p prueba der:{(p_prueba):.4f}; dos colas= {p_prueba}')
    ax.axvline(t_critico_izquierda, color='red', linestyle='--', label=f'Valor t Crítico (izquierda): {t_critico_izquierda:.4f}')
    #ax.axvline(t_critico_derecha, color='red', linestyle='--', label=f'Valor Z Crítico (derecha): {t_critico_derecha:.4f}')
    ax.axvline(t_calculado_izq, color='green', linestyle='--', label=f'Valor t Calculado: {t_calculado_izq:.4f}')
    #ax.axvline(t_calculado_der, color='green', linestyle='--', label=f'Valor t Calculado: {t_calculado_der:.4f}')
    ax.set_xlabel('t')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (cola izquierda)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

# Función que visualiza valor crítico de t cola a la izquierda
def f_aceptar_rechazar_Ho_cola_derecha(valor_contraste, confianza, gl, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = t.pdf(x, df= gl)

    alfa = 1 - confianza
    # Definir los valores críticos para un nivel de significancia del 5%
    t_critico_derecha = t.ppf(1 - alfa, df= gl )


    # Valor de t calculado, por el momento es un valor arbitrario solo para explicación
    t_calculado = valor_contraste

    # Visualización en los ejes proporcionados
    ax.plot(x, y, 'b-', label='Distribución t Student'+" ;"+ str(gl))

    ax.fill_between(x, 0, y, where=(x >= t_critico_derecha), color='red', alpha=0.5, label='Área de Rechazo (derecha)')

    ax.axvline(t_critico_derecha, color='red', linestyle='--', label=f'Valor Crítico (derecha): {t_critico_derecha:.4f}')
    ax.axvline(t_calculado, color='green', linestyle='--', label=f'Valor Calculado: {t_calculado:.4f}')
    ax.set_xlabel('t')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis.(Cola Derecha)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

# Esta función visualiza las probabilidad p_value y p_prueba a distintos niveles de confoanza
# Cola a la derecha
def f_aceptar_rechazar_Ho_cola_derecha_p_value(valor_contraste, confianza, gl, ax):
    # Definir valores para el eje x
    x = np.linspace(-3, 3, 1000)

    # Calcular la densidad de probabilidad de la distribución normal estándar
    y = t.pdf(x, df=gl)

    alfa = 1 - confianza
    # Definir las áreas para un nivel de significancia del 5%
    t_critico_derecha = t.ppf(1 - alfa, df=gl)
    #print (t_critico_derecha)

    # Valor de t calculado, por el momento es un valor arbitrario solo para explicación
    t_calculado_der = valor_contraste
    #t_calculado_der = abs(valor_contraste)

    p_value = np.round(alfa, 4)

    p_prueba = np.round(1 - stats.t.cdf(t_calculado_der, df=gl), 4)

    # Visualización en los ejes proporcionados

    ax.plot(x, y, 'b-', label='Distribución t Student '+'; gl='+str(gl))
    #ax.fill_between(x, 0, y, where=(x <= t_critico_izquierda), color='red', alpha=0.5, label=f'p_value (izq):{p_value:.4f}')
    ax.fill_between(x, 0, y, where=(x >= t_critico_derecha), color='red', alpha=0.5, label=f'p_value (der):{(p_value):.4f}')
    #ax.fill_between(x, 0, y, where=(x <= t_calculado_izq), color='green', alpha=0.3, label=f'p_prueba (izq):{p_prueba:.4f}')
    ax.fill_between(x, 0, y, where=(x >= t_calculado_der), color='green', alpha=0.3, label=f'p prueba der:{(p_prueba):.4f}')
    #ax.axvline(t_critico_izquierda, color='red', linestyle='--', label=f'Valor t Crítico (izquierda): {t_critico_izquierda:.4f}')
    ax.axvline(t_critico_derecha, color='red', linestyle='--', label=f'Valor t Crítico (derecha): {t_critico_derecha:.4f}')
    #ax.axvline(t_calculado_izq, color='green', linestyle='--', label=f'Valor t Calculado: {t_calculado_izq:.4f}')
    ax.axvline(t_calculado_der, color='green', linestyle='--', label=f'Valor t Calculado: {t_calculado_der:.4f}')
    ax.set_xlabel('t')
    ax.set_ylabel('Densidad de probabilidad')
    ax.set_title('Prueba de Hipótesis. (cola derecha)'+" Confianza:"+str(confianza*100))
    ax.legend()
    ax.grid(False)

# Esta función devuelve la decisión de acepar o rechzar H0
# Recibe los parámetros: confianza, la media de comparacióno estiamda, la media de la muestra,
# la desviación estándar de la muestra, el valor de n en grados de libertad y el tipo de hipótesis para saber el valor de alfa
# y conocer los valores críticos de t.
# Devuelve gráfica y la decisión de aceptar o rechazar Ho
def f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std, gl, tipo):

  decision = ""

  alfa = 1 - confianza
  n = gl + 1 # Grados de libertad mas 1 es el tamaño de la muestra
  # Es una hipótesis a dos colas
  if tipo == "D": # Es una hipótesis a dos colas
    t_critico = t.ppf(1 - alfa / 2, df=gl)
    t_calculado = (media_muestra - media_estimada) / (desv_std / np.sqrt(n))

    print ("t critico a ambos lados", t_critico)
    print ("t calculado", t_calculado)
    if (t_calculado < -t_critico) or (t_calculado > t_critico):
      decision = "Se rechaza"
    else:
      decision = "Se acepta"

    # Manda llamar la gráfica con los valores críticos de t y t calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = t_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_dos_colas(valor_contraste, confianza, gl, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()


  # Es una hipótesis cola izquierda
  if tipo == "I": # Es una hipótesis a la izquierda
    t_critico = t.ppf(alfa, df=gl)
    t_calculado = (media_muestra - media_estimada) / (desv_std / np.sqrt(n))

    print ("t critico a la izquierda", t_critico)
    print ("t calculado", t_calculado)
    if (t_calculado < t_critico):
      decision = "Se rechaza"
    else:
      decision = "Se acepta"

    # Manda llamar la gráfica con los valores cíticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = t_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_izquierda(valor_contraste, confianza, gl, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  # Es una hipótesis cola a la derecha
  if tipo == "R": # Es una hipótesis a la derecha
    t_critico = t.ppf(1 - alfa, df=gl)
    t_calculado = (media_muestra - media_estimada) / (desv_std / np.sqrt(n))

    print ("t critico a la derecha", t_critico)
    print ("t calculado", t_calculado)
    if (t_calculado > t_critico):
      decision = "Se rechaza"
    else:
      decision = "Se acepta"

    # Manda llamar la gráfica con los valores cíticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = t_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_derecha(valor_contraste, confianza, gl, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  return decision

# Esta función devuelve la decisión de acepar o rechzar H0 conforme valores p_prueba
# Recibe los parámetros: confianza, la media estimada , la media de la muestra,
# la desviación estándar de la muestra, el valor de n en grados de libertdad gl y el tipo hipótesis
# Devuelve gráfica y la decisión de aceptar o rechazar Ho
def f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std_poblacion, gl, tipo):

  decision = ""

  alfa = 1 - confianza
  # Es una hipótesis a dos colas
  if tipo == "D": # Es una hipótesis a dos colas
    t_critico = t.ppf(1 - alfa / 2, df=gl)
    t_calculado = (media_muestra - media_estimada) / (desv_std / np.sqrt(n))

    print ("t critico a ambos lados", t_critico)
    print ("t calculado", t_calculado)

    # Definir las áreas para un nivel de significancia del 10%, 5% o 1%
    t_critico_izquierda = t.ppf(alfa / 2, df=gl)
    t_critico_derecha = t.ppf(1 - alfa / 2, df=gl)

    # Valor de t calculado
    t_calculado_izq = -(abs(t_calculado))
    t_calculado_der = abs(t_calculado)

    p_value = np.round(alfa, 4)

    p_prueba = np.round(stats.t.cdf(t_calculado_izq, df=gl) + (1 - stats.t.cdf(t_calculado_der, df=gl)), 4)

    print ("Valor de p_prueba", p_prueba)
    print ("Valor de p_value", p_value)
    print ("Evaluando probabilidades ... ")
    f_evaluar_p_prueba_p_value_ho(p_prueba, p_value)

    # Manda llamar la gráfica con los valores críticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = t_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_dos_colas_p_value(t_calculado, confianza, gl, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  # Es una hipótesis cola izquierda
  if tipo == "I": # Es una hipótesis cola a la izquierda
    t_critico = t.ppf(alfa, df=gl)
    t_calculado = (media_muestra - media_estimada) / (desv_std / np.sqrt(n))

    print ("t critico a la izquierda", t_critico)
    print ("t calculado", t_calculado)

    # Definir las áreas para un nivel de significancia del 10%, 5% 1%
    t_critico_izquierda = t.ppf(alfa, df=gl)
    #t_critico_derecha = norm.ppf(1 - alfa / 2, df=gl)

    # Valor de t calculado
    t_calculado_izq = t_calculado
    #t_calculado_der = abs(t_calculado)

    p_value = np.round(alfa, 4)

    p_prueba = np.round(stats.t.cdf(t_calculado_izq, df=gl), 4)

    print ("Valor de p_prueba", p_prueba)
    print ("Valor de p_value", p_value)
    print ("Valuando probabilidades ... ")
    f_evaluar_p_prueba_p_value_ho(p_prueba, p_value)

    # Manda llamar la gráfica con los valores críticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = t_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_izquierda_p_value(t_calculado, confianza, gl, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  # Es una hipótesis cola a la derecha
  if tipo == "R": # Es una hipótesis cola a la derecha
    t_critico = t.ppf(1 - alfa, df=gl)
    t_calculado = (media_muestra - media_estimada) / (desv_std / np.sqrt(n))

    print ("t critico a la derecha", t_critico)
    print ("t calculado", t_calculado)

    # Definir las áreas para un nivel de significancia del 10%, 5% o 1%
    #_critico_izquierda = t.ppf(alfa, df=gl)
    t_critico_derecha = t.ppf(1 - alfa, df=gl)

    # Valor de t calculado
    #t_calculado_izq = t_calculado
    t_calculado_der = t_calculado

    p_value = np.round(1 - alfa, 4)

    p_prueba = np.round(1 - stats.t.cdf(t_calculado_der, df=gl), 4)

    print ("Valor de p_prueba", p_prueba)
    print ("Valor de p_value", p_value)
    print ("Valuando probabilidades ... ")
    f_evaluar_p_prueba_p_value_ho(p_prueba, p_value)

    # Manda llamar la gráfica con los valores críticos de z y z calculado
    confianzas = [0.90, 0.95, 0.99]
    valor_contraste = t_calculado
    # Crear una figura con una fila y tres columnas
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    # Llamar a la función para cada confianza y mostrar la gráfica correspondiente
    for i, confianza in enumerate([0.90, 0.95, 0.99]):
      f_aceptar_rechazar_Ho_cola_derecha_p_value(t_calculado, confianza, gl, axs[i])

    # Ajustar espaciado y mostrar las gráficas
    plt.tight_layout()
    plt.show()

  return decision

def f_evaluar_p_prueba_p_value_ho(p_prueba, p_value):
  if (p_prueba < p_value):
    print ("Se rechaza Ho")
  else:
    print ("Se acepta Ho")

# %% [markdown]
# ## Valores críticos de $t$ para contraste a 10 grados de libertdad.
#
# Los valores críticos de $t$ dependen del nivel de confianza y de los grados de libertad es decir, $n-1$ siendo $n$ el tamaño de la muestra.
#
# Los valores críticos de $t$ es el valor de $t$ en el eje horizontal en donde se cruza con la curva de densidad de la distribución $t$ con respeco a una probabilidad. Ver visualizaciones las líneas punteadas en rojo y el cruce con el eje horizontal.
#
# La siguente tabla identifica los valores críticos de $t$ a $gl=10$ diez grados de libertdas que pudieran servir para realizar el contraste.
#
# Estos valores se pueden calcular con la función *t.ppf(confianza, df=)* de python: :
#
# | Confianza | Alfa | Z (Dos colas) $α/2_{gl=10}$ | Z (Izquierda) $α_{gl=10}$ | Z (Derecha) $1-α_{gl=10} $       ° |
# |-----------|------|-------------|-------------------|-------------|
# | 0.90      | 0.10 | 1.8125      | -1.3722      | 1.3722               |
# | 0.95      | 0.05 | 2.2281      | -1.8125      | 1.8125           |
# | 0.99      | 0.01 | 3.1693      | -2.7638      | 2.7638               |
#
# Para extrar los valores críticos de $t$ para diferentes niveles de confianza en Python, se puede utilizar la función *ppf()* de la distribución *t student* de scipy.stats.
#
# Ejemplo Python: a distintos niveles de confianza del 90%, 95% y 99%:

# %% [markdown]
# Para extrar los valores críticos de  $t$  para diferentes niveles de confianza en Python, se puede utilizar la función ppf() de la distribución *t student* de scipy.stats.
#
# Ejemplo Python: a distintos niveles de confianza del 90%, 95% y 99% y 10 grados de libertad:

# %%
confianza = [0.90, 0.95, 0.99]
gl = 10
alfa = [1 - c for c in confianza]

for c, a in zip(confianza, alfa):
    t_dos_colas = t.ppf(1 - a / 2, df = gl)
    t_izquierda = t.ppf(a, df = gl)
    t_derecha = t.ppf(1 - a, df = gl)
    print(f"Confianza: {c:.2f}, Alfa: {a:.2f}, t (Dos colas) {t_dos_colas:.4f}, t (Izquierda): {t_izquierda:.4f}, t (Derecha): {t_derecha:.4f}")
# Out:
# Confianza: 0.90, Alfa: 0.10, t (Dos colas) 1.8125, t (Izquierda): -1.3722, t (Derecha): 1.3722
# Confianza: 0.95, Alfa: 0.05, t (Dos colas) 2.2281, t (Izquierda): -1.8125, t (Derecha): 1.8125
# Confianza: 0.99, Alfa: 0.01, t (Dos colas) 3.1693, t (Izquierda): -2.7638, t (Derecha): 2.7638

# %% [markdown]
# ## Hipótesis a dos colas
#
# Se visualiza el valor de un $t$ arbitrariamente definido contrastado contra los valores críticos de $t$ extraídos a partir del nivel de confianza y del valor de alfa a dos colas.
#
# Los niveles de confianza son los radicionales al $90$%, $95$% y $99$% por lo que alfa se dive el $α/2$, tanto a la izuierda como a la derecha.

# %%
confianzas = [0.90, 0.95, 0.99]
valor_contraste = -2.5
gl = 10
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate([0.90, 0.95, 0.99]):
    f_aceptar_rechazar_Ho_dos_colas(valor_contraste, confianza, gl, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si el valor del $t$ calculado (línea punteada verde) está dentro de zona de aceptación es decir entre las dos líneas rojas punteadaso los valores críticos de $t$, entonces se acepta la $H_0$, de lo contrario, se rechaza la $H_0$, sea cual sea la hipótesis y de acuerdo al contexto.
#
# Entonces ¿Cómo calcular el valor de $t$ contrastar con los valores críticos de $t$ de acuerdo a la probabilidad?.
#
# $$
# t = \frac{{\bar{x} - \mu}}{{S/ \sqrt{n}}}
# $$

# %% [markdown]
# Ahora se visualiza el contraste de la probabilidad de dos veces $t$ con respecto a *p_value*.
#
# Con un valor de $t$ definido como una constante por el momento como puede ser como puede ser $t=-2.5$, se calcula la probabilidad de que $t$ esté entre $-2.5$ y $2.5$, razón por la que se interpreta que es una probabilidad a dos colas.
#
# Los valores de *t crítico* que dividen la zona de aceptación y rechazo al $95$% son de $-2.2281$ y $+2.2281$ a 10 grados de libertdad.
#
# Ahora bien la probabilidad es de $0.05$ que es el área de rechazo de una hipótesis nula; esta probabildia es $p_value = 0.05$ significa que el valor de la probabilidad encontrada de *p_prueba* con repecto a $t$ si es menor a *p_value* tal vez $0.05$ se rechaza la $H_0$.
#
# Usando *t student*, es necesario el argumento de los grados de libertad por el momento en $gl=10$.

# %%
confianza = 95/100
alfa = 1 - confianza
gl = 10    # (n-1)

t_izq = -2.2281
t_der = 2.2281
# A dos colas

print ("Hipótesis a dos colas: ", confianza*100, " % de confianza")
print ("p value")
print ("Probabilidad t = ", t_izq, " = ", np.round(stats.t.cdf(t_izq, df=gl), 4))
print ("Probabilidad zt= ", t_der, " = ", np.round(1 - stats.t.cdf(t_der, df=gl), 4 ))
p_value = stats.t.cdf(t_izq, df=gl) + 1- stats.t.cdf(t_der, df=gl)
print ("p_value", np.round(p_value, 4))


tx = -2.5 # El valor de contraste de t, el que será calculado
print()
print("p prueba con respecto a t = ")
print("Probabilidad t del lado izquierdo =", tx, "=", np.round(stats.t.cdf(tx, df=gl), 4))
print("Probabilidad t del lado derecho =", abs(tx), "=", np.round(1 - stats.t.cdf(abs(tx), df=gl), 4))

print ("p_prueba")
p_prueba = stats.t.cdf(tx, df=gl) + (1 - stats.t.cdf(abs(tx), df=gl))

print ("p_prueba sumado porque es a dos colas", np.round(p_prueba, 4))

print ()
print ("La decisión de Ho es ...")
f_evaluar_p_prueba_p_value_ho(p_prueba, p_value)
# Out:
# Hipótesis a dos colas:  95.0  % de confianza
# p value
# Probabilidad t =  -2.2281  =  0.025
# Probabilidad zt=  2.2281  =  0.025
# p_value 0.05
#
# p prueba con respecto a t =
# Probabilidad t del lado izquierdo = -2.5 = 0.0157
# Probabilidad t del lado derecho = 2.5 = 0.0157
# p_prueba
# p_prueba sumado porque es a dos colas 0.0314
#
# La decisión de Ho es ...
# Se rechaza Ho

# %% [markdown]
# La siguiente llamada de la función *f_aceptar_rechazar_Ho_dos_colas_p_value()* a diez grados de libertad, se visualizan las probabilidad de *p_value* que son de acuerdo a los niveles de confianza *(0.90, 095, 0.99)* y las probabilidades de *p_prueba* con respecto al mismo valor de $t=-2.5$ previamte inicializado, con ello  representar el contraste usando las probabilidades para aceptar o rechazar $H_0$ a dos colas.

# %%
## Llamando y visualziando contraste con p_prueba y p_value
confianzas = [0.90, 0.95, 0.99]
tx = -2.5 # El valor de contraste de t, el que será calculado
gl = 10
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate(confianzas):
  f_aceptar_rechazar_Ho_dos_colas_p_value(tx, confianza, gl, axs[i])

# Ajustar espaciado y mostrar las gráficas

plt.tight_layout()
plt.show()

# %% [markdown]
# Si el área en color verde es mayor que el área en color rojo se acepta la $H_0$, de lo contrario si el área es más pequeña se rechaza $H_0$ que significa que hay evidencia estadística para rechazar la hipótesis.

# %% [markdown]
# ## Hipótesis cola a la izquierda
#
# Se visualiza el valor de un  t  crítico arbitrariamente definido contrastado contra el valor de  t  extraído a partir del nivel de confianza cola a la izquierda.
#
# Los niveles de confianza son los tradicionales al  90 %,  95 % y  99 % por lo que alfa  1 − confianza , solo a la izquierda.

# %%
confianzas = [0.90, 0.95, 0.99]
valor_critico = -1.5
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

gl = 10 # Diez grados de libertdad
# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate(confianzas):
    f_aceptar_rechazar_Ho_cola_izquierda(valor_critico, confianza, gl, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si la línea punteada en color verde está en zona de rechazo pues se rechaza $H_0$, de lo contrario si está en zona de aceptación o mayor que la linea crítica punteada en color rojo a la izquierda pues se acepta $H_0$.
#
# Entonces, nuevamente, ¿cómo calcular el valor de $t$ y contrastarlo con los valores críticos de $t$ de acuerdo a la probabilidad?.
#
# $$
# t = \frac{{\bar{x} - \mu}}{{S / \sqrt{n}}}
# $$

# %% [markdown]
# Ahora se visualiza el contraste de la probabilidad a la izquierda de  $t$  con respecto a *p_value*.
#
# Con un valor de  $t$  definido como una constante por el momento como puede ser como puede ser  $t= −1.5$ , se calcula la probabilidad de que $t$ solamente por la izquierda. El valor de $t$ para definir zona de aceptación o rechazo se toma el valor al 95% de $t= -1.8125$  a diez grados de libertdad $gl=10$.
#
# Ahora bien la probabilidad es de  $0.05$  que es el área de rechazo de una hipótesis nula; esta probabilidad es  *p_value=0.05* significa que el valor de la probabilidad encontrada  *p_value* con repecto a $t$ si es menor a $0.05$ se rechaza la  $H_0$.

# %%
confianza = 95/100
alfa = 1 - confianza

gl = 10
t_izq = -1.8125
# cola a la izquierda

print ("Hipótesis cola a la izquierda: ")
print ("p value")
print ("Probabilidad t = ", t_izq, " = ", np.round(stats.t.cdf(t_izq, df=gl) , 4))
p_value = stats.t.cdf(t_izq, df=gl)
print ("p_value", np.round(p_value, 4))


tx =  -1.5 # Usando el mismo valor de contraste
print()
print ("p prueba con respecto a t = ")
print ("Probabilidad t del lado izquierdo= ", tx, " = ", np.round(stats.t.cdf(tx, df=gl), 4))

print ("p_prueba")
p_prueba = stats.t.cdf(tx, df= gl)

print ("p_prueba cola a la izquierda", np.round(p_prueba, 4))

print ()
print ("La decisión de Ho es ...")
f_evaluar_p_prueba_p_value_ho(p_prueba, p_value)
# Out:
# Hipótesis cola a la izquierda:
# p value
# Probabilidad t =  -1.8125  =  0.05
# p_value 0.05
#
# p prueba con respecto a t =
# Probabilidad t del lado izquierdo=  -1.5  =  0.0823
# p_prueba
# p_prueba cola a la izquierda 0.0823
#
# La decisión de Ho es ...
# Se acepta Ho

# %% [markdown]
# La siguiente llamada de la función *f_aceptar_rechazar_Ho_cola_izquierda_p_value()* visualiza las probabilidad de *p_value* que son de acuerdo a los niveles de confianza *(0.90, 0.95, 0.99)* y las probabilidades de *p_prueba* con respecto al mism valor de $t=-1.5$ previamente inicializado, con ello  representar el contraste usando las probabilidades para aceptar o rechazar $H_0$ cola izquierda a diez grados de libertad $gl=10$.

# %%
## Llamando y visualziando contraste con p_prueba y p_value

confianzas = [0.90, 0.95, 0.99]
gl = 10
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate([0.90, 0.95, 0.99]):
  f_aceptar_rechazar_Ho_cola_izquierda_p_value(tx, confianza, gl, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si el área sombreada que representa *p_prueba* en color verde es mayor que el area de *p_value* en color rojo se acepta $H_0$ de lo contrario si *p_prueba* es menor que *p_value* se rechaza $H_0$.

# %% [markdown]
# ## Hipótesis cola a la derecha
#
# Se visualiza el valor de $t$  arbitrariamente definido contrastado contra el valor crítico de $t$ extraído a partir del nivel de confianza cola a la derecha a diez grados de libertdad $gl=10$.
#
# Los niveles de confianza son los tradicionales al $90$%, $95$% y $99$% por lo que alfa $1-confianza$, solo a la derecha.

# %%
confianzas = [0.90, 0.95, 0.99]
gl = 10
valor_critico = 1.5
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate(confianzas):
    f_aceptar_rechazar_Ho_cola_derecha(valor_critico, confianza, gl, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# Si la línea punteada de contraste que representa al valor de *t* calculado en color verde está por debajo de la línea punteada en color rojo, entonces se acepta $H_0$ de lo contrario se rechaza.
#
# Entonces, nuevamente la pregunta, ¿cómo calcular el valor de $t$ y que pueda se contrastado contra el valor crítico de $t$ de acuerdo a la probabilidad?.
#
# $$
# t = \frac{{\bar{x} - \mu}}{{S / \sqrt{n}}}
# $$

# %% [markdown]
# Ahora se visualiza el contraste de la probabilidad a la derecha de  *t*  con respecto a *p_value* a diez grados de libertdad, $gl=10$.
#
# Con un valor de  t  definido como una constante por el momento como puede ser como puede ser  t=1.5  , se calcula la probabilidad de que  t  solamente por la derecha. El valor de  t  para definir zona de aceptación o rechazo se toma el valor al 95% de  z=1.8125 a die grados de libertdad $gl=10$.
#
# Ahora bien la probabilidad es de  *0.05*  que es el área de rechazo de una hipótesis nula; esta probabilidad es *p_value=0.05*. Entonces, la prueba consiste en que si el valor de la probabilidad encontrada *p_prueba* con repecto a  *t*  es menor a  *0.05*  se rechaza la  $H_0$.

# %%
confianza = 95/100
gl=10
alfa = 1 - confianza

t_der = 1.8125
# cola a la derecha

print ("Hipótesis cola a la derecha: ")
print ("p value")
print ("Probabilidad t = ", t_der, " = ", np.round(1 - stats.t.cdf(t_der, df = gl) , 4))
p_value = 1 - stats.t.cdf(t_der, df=gl)
print ("p_value", np.round(p_value, 4))


tx =  1.5 # Usando el mismo valor de contraste
print()
print ("p prueba con respecto a t = ")
print ("Probabilidad t del lado derecho= ", tx, " = ", np.round(1 - stats.t.cdf(tx, df=gl), 4))

print ("p_prueba")
p_prueba = 1 - stats.t.cdf(tx, df = gl)

print ("p_prueba cola a la derecha", np.round(p_prueba, 4))

print ()
print ("La decisión de Ho es ...")
f_evaluar_p_prueba_p_value_ho(p_prueba, p_value)
# Out:
# Hipótesis cola a la derecha:
# p value
# Probabilidad t =  1.8125  =  0.05
# p_value 0.05
#
# p prueba con respecto a t =
# Probabilidad t del lado derecho=  1.5  =  0.0823
# p_prueba
# p_prueba cola a la derecha 0.0823
#
# La decisión de Ho es ...
# Se acepta Ho

# %% [markdown]
# La siguiente llamada de la función *f_aceptar_rechazar_Ho_cola_derecha_p_value()* visualiza las probabilidad de *p_value* que son de acuerdo a los niveles de confianza *(0.90, 095, 0.99)* a diez grados de libertad y las probabilidades de *p_prueba* con respecto al mismo valor de $t=1.5$ previamente inicializado, con ello  representar el contraste usando las probabilidades para aceptar o rechazar $H_0$ cola derecha.

# %%
## Llamando y visualziando contraste con p_prueba y p_value
confianzas = [0.90, 0.95, 0.99]
# Crear una figura con una fila y tres columnas
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Llamar a la función para cada confianza y mostrar la gráfica correspondiente
for i, confianza in enumerate([0.90, 0.95, 0.99]):
  f_aceptar_rechazar_Ho_cola_derecha_p_value(tx, confianza, gl, axs[i])

# Ajustar espaciado y mostrar las gráficas
plt.tight_layout()
plt.show()

# %% [markdown]
# De manera similar si el valor *p_prueba* es menor que *p_value* se rechaza $H_0$ o lo que es lo mismo, si el área en color verde es menor que el área en color rojo se rechaza $H_0$.

# %% [markdown]
# ## Ejercicios
#
# Se plantean varios ejercicios de prueba de hipótesis con la distribución *t student*; primero a dos colas, luego cola a la izquierda y finalmente un ejercico cola a la derecha.
#
# La prueba de hipótesis describe el contexto de cada ejercicio, la inicialización de datos y la llamada de las funciones adecuadas con los argumentos pertinentes, entre ellos, el tipo de hipótesis y los grados de libertdad.

# %% [markdown]
# ### Ejercicio 1 a dos colas $\mu=100$
#
# Se desea probar si la media de una muestra de $n=25$ elementos es igual a $\mu=100$ a partir de la muestra en donde la media encontrada es $\bar{x}= 102$ y desviación estándar de 10 $S=10$.
#
# La hipótesis nula es que la media es $H_0: \mu = 100$ y la hipótesis alternativa es que la media es diferente de 100, $H_a \ne 100$. Se utiliza un nivel de significancia del $5$% es decir $95$% de confianza. $\alpha = 0.05$ a dos colas., $\alpha/2 = 0.025$ de cada cola.
#
# Se utiliza distribución *t student* dado que la muestra es pequeña además de que no se conoce la desviación estándar de la población.
#
# #### Hipótesis: a dos colas
# $$
# H_0: \mu = 100
# $$
#
# $$
# H_a: \mu \ne 100
# $$
#
# #### Los datos iniciales
#
# * $n = 25$
# * $gl = (n-1) = 24$
# * $confianza = 0.95$
# * $\alpha = 0.05$
# * $\alpha/2 = 0.025$
# * $\mu = 100$
# * $\bar{x} = 102$
# * $S = 10$

# %%
n = 25
gl = n-1
confianza = 95/100
media_estimada = 100
media_muestra = 102
desv_std = 10
print ("Datos iniciales")
print ("Confianza %: ", confianza* 100, "; relativo", confianza)
print ("n:", n)
print ("gl:", gl)
print ("media_estimada:", media_estimada)
print ("media_muestra:", media_muestra)
print ("desv_std:", desv_std )
# Out:
# Datos iniciales
# Confianza %:  95.0 ; relativo 0.95
# n: 25
# gl: 24
# media_estimada: 100
# media_muestra: 102
# desv_std: 10

# %% [markdown]
# Se hace la prueba de hipótesis con t calculado contrastado con t criticos además de calcular el valor de la probabilida para contrastarlo contra *p_value*.
#
# ¿Cuál es el valor de *t calculado*?
#
# $$
# \begin{aligned}
# t &= \frac{\bar{x} - \mu}{S\sqrt{n}} \\
# &= \frac{102 - 100}{10/\sqrt{25}} \\
# &= \frac{2}{10/5} \\
# &= \frac{2}{2} \\
# &= 1
# \end{aligned}
# $$

# %% [markdown]
# Siendo el valor crítico de *t* al $95$% de confianza igual a $\pm 2.0638$ y el valor de $t$ calculado o de contraste igual a $1$, entonces se anticipa que el valor de $t$ está en zona de confianza, por lo que se acepta $H_0$ a dos colas.
#
# Al mandar llamar la función *f_aceptar_rechazar_ho()* con los parámetros adecuados indicándole que es a dos colas tipo='D' y los grados de libertdad $gl$ se conoce la decisión de aceptar o rechazar $H_0$.
#
# De igual forma al mandar ejecuar la función *f_aceptar_rechazar_ho_p_value_p_prueba()* se calcula la probabilidad que permite contrastarse u observarse visualmente la probabilidad *p_prueba* contra *p_value* para finalmente tomar la decisión de aceptar o rechazar $H_0$.

# %%
H0 = "La media de la población no es diferente de 100"
decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std, gl, "D")
print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std, gl, "D")
# Out:
# t critico a ambos lados 2.0638985616280205
# t calculado 1.0
# Se acepta H0: La media de la población no es diferente de 100 con nivel de confianza del 95.0 %
# t critico a ambos lados 2.0638985616280205
# t calculado 1.0
# Valor de p_prueba 0.3273
# Valor de p_value 0.05
# Evaluando probabilidades ...
# Se acepta Ho
# ''

# %% [markdown]
# Para este ejercicio 1, se acepta $H_0: \text{la media de la población no es diferente de 100}$, dado que el valor de *t de contraste* está en zona de confianza por encima y por debajo de los *valores críticos de t*; además se confirma que la probabilidad *p_prueba* es mayor que la probabilidad *p_value* a un nivel de confianza del $95$%.
#
# No hay elementos suficientes para rechazar la hipótesis nula.

# %% [markdown]
# ### Ejercicio 2. Cola a laizquierda. Rendimiento deportivo
#
# Se quiere determinar si un nuevo método de entrenamiento mejora el tiempo de reacción de los atletas en comparación con el método tradicional.
#
# El método tradicional tiene un tiempo de reacción medio de 0.25 segundos $\mu=0.25$.
#
# El objetivo es determinar si el nuevo método de entrenamiento puede reducir el tiempo de reacción promedio de los atletas.
#
# #### Hipótesis: cola izquierda
#
# Hipótesis nula ($H_0$): "*El nuevo método de entrenamiento no mejora el tiempo de reacción promedio de los atletas o lo hace peor que el método tradicional*". $\mu \geq 20$.
# Hipótesis alternativa ($H_a$): "*El nuevo método de entrenamiento mejora el tiempo de reacción promedio de los atletas*". $\mu < 20$.
#
# $$
# H_0: \mu \ge 20
# $$
#
# $$
# H_a: \mu < 20
# $$
#
# El nivel de confianza es estima al $90$% y el tamaño de la muestra es 30 atletas. es decir $gl = 29$; la media de la muestr es $\bar{x}=19.95$, desviacion estándar de $S=0.02$
#
# #### Los datos iniciales
#
# * $n = 30$
# * $gl = (n-1) = 29$
# * $confianza = 0.90$
# * $\alpha = 0.01$
# * $\mu = 20$
# * $\bar{x} = 19.95$
# * $S = 0.02$

# %%
n = 30
gl = n-1
confianza = 90/100
media_estimada = 20.00
media_muestra = 19.95
desv_std = 0.2
print ("Datos iniciales")
print ("Confianza %: ", confianza* 100, "; relativo", confianza)
print ("n:", n)
print ("gl:", gl)
print ("media_estimada:", media_estimada)
print ("media_muestra:", media_muestra)
print ("desv_std:", desv_std )
# Out:
# Datos iniciales
# Confianza %:  90.0 ; relativo 0.9
# n: 30
# gl: 29
# media_estimada: 20.0
# media_muestra: 19.5
# desv_std: 0.2

# %% [markdown]
# $$
# \begin{aligned}
# t &= \frac{\bar{x} - \mu}{S\sqrt{n}} \\
# &= \frac{19.95 - 20.00}{0.2/\sqrt{30}} \\
# &= \frac{-0.5}{0.2/5.4772} \\
# &= \frac{-0.5}{0.0365} \\
# &= -1.3693
# \end{aligned}
# $$

# %%
print((media_muestra-media_estimada))
print(np.sqrt(n))
print(desv_std/np.sqrt(n))
print((media_muestra-media_estimada)/(desv_std/np.sqrt(n)))
# Out:
# -0.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d929d9b81ffc> in <cell line: 2>()
#       1 print((media_muestra-media_estimada))
# ----> 2 print(np.sqrt(n))
#       3 print(desv_std/np.sqrt(n))
#       4 print((media_muestra-media_estimada)/(desv_std/np.sqrt(n)))
#
# NameError: name 'np' is not defined

# %%
H0 = "El nuevo método de entrenamiento no mejora el tiempo de reacción promedio de los atletas o lo hace peor que el método tradicional de 20 segs."
decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std, gl, "I")
print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std, gl, "I")
# Out:
# t critico a la izquierda -1.3114336505076971
# t calculado -1.3693063937629348
# Se rechaza H0: El nuevo método de entrenamiento no mejora el tiempo de reacción promedio de los atletas o lo hace peor que el método tradicional de 20 segs. con nivel de confianza del 90.0 %
# t critico a la izquierda -1.3114336505076971
# t calculado -1.3693063937629348
# Valor de p_prueba 0.0907
# Valor de p_value 0.1
# Valuando probabilidades ...
# Se rechaza Ho
# ''

# %% [markdown]
# Se observa que al $90$% de confianza el valor de *t calculado= -1.33693* está por debajo del valor crítico a la izquierda *-1.3114*. Ademas que la probabilidad *p_prueba=0.09* es menor que *p.value=0.10* razón que confirma el rechazo de $H_0$.
#
# Rechazo al $90$% de confianza: Significa que, al nivel de confianza del 90%, los datos proporcionan suficiente evidencia para rechazar la hipótesis nula $H_0$ en favor de la alternativa $H_a$.
#
# Aceptación al $95$% y $99$% de confianza: Al aumentar el nivel de confianza al $95$% y $99$%, se vuelve más difícil rechazar la hipótesis nula. Esto puede deberse a que, con un nivel de confianza más alto, se requiere una mayor evidencia en contra de la hipótesis nula $H_0$ para rechazarla.

# %% [markdown]
# ### Ejercicio 3. Cola a la derecha. Medicamento para colesterol
#
# Se está realizando un estudio para evaluar si un nuevo medicamento reduce el nivel de colesterol en pacientes con riesgo cardiovascular.
#
# Se toma una muestra aleatoria de $n=20$ pacientes y se les administra el medicamento durante un mes.
#
# El nivel de colesterol se mide para cada paciente. Se quiere determinar si hay evidencia suficiente para afirmar que el medicamento no reduce el nivel de colesterol comparado a un valor de 230.
#
# Aqui las muestras de los valores de colesterol
#
# {205, 195, 220, 240, 185, 210, 225, 230, 215, 200, 190, 205, 235, 195, 210, 220, 225, 230, 240, 185}
#
#
# #### Hipótesis: cola a la derecha
# $$
# H_0: \mu \ge 230
# $$
#
# $$
# H_a: \mu < 230
# $$
#
# #### Los datos iniciales

# %%
# Datos de la muestra
confianza = 95/100
muestra = [205, 195, 220, 240, 185, 210, 225, 230, 215, 200,
           190, 205, 235, 195, 210, 220, 225, 230, 240, 185]
n = len(muestra)
gl = n-1
confianza = 95/100
media_estimada = 230
media_muestra = np.mean(muestra)
desv_std = np.std(muestra)
print ("Datos iniciales")
print ("Confianza %: ", confianza* 100, "; relativo", confianza)
print ("n:", n)
print ("gl:", gl)
print ("media_estimada:", media_estimada)
print ("media_muestra:", media_muestra)
print ("desv_std:", desv_std )
# Out:
# Datos iniciales
# Confianza %:  95.0 ; relativo 0.95
# n: 20
# gl: 19
# media_estimada: 230
# media_muestra: 213.0
# desv_std: 17.277152543170995

# %% [markdown]
# ¿Cuál es el valor de t calculado?
#
# $$
# \begin{aligned}
# t &= \frac{\bar{x} - \mu}{S\sqrt{n}} \\
# &= \frac{213 - 230}{17.2771/\sqrt{20}} \\
# &= \frac{-17}{17.2771/4.4721} \\
# &= \frac{-17}{3.8633} \\
# &= -4.4003
# \end{aligned}
# $$
#
# Dado que el valor *calculado de t* está muy por debajo de un valor *t_critico* a $19$ grados de libertdad $gl=19$ a un 95% e confianza de 1.7291

# %% [markdown]
# Se manda llamar la función *f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std, gl, "R")* y *f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std, gl, "R")
# * con argumenos adecuados incluídos el tipo de hipótesis a la derecha "R" y los grados de libertdad $n-1$, enre otros.

# %%
H0 = "La media de la población no menor que 230"
decision = f_aceptar_rechazar_ho(confianza, media_estimada, media_muestra, desv_std, gl, "R")
print (decision, "H0:", H0, "con nivel de confianza del", confianza*100, "%")
f_aceptar_rechazar_ho_p_value_p_prueba(confianza, media_estimada, media_muestra, desv_std, gl, "R")
# Out:
# t critico a la derecha 1.729132811521367
# t calculado -4.400395901177777
# Se acepta H0: La media de la población no menor que 230 con nivel de confianza del 95.0 %
# t critico a la derecha 1.729132811521367
# t calculado -4.400395901177777
# Valor de p_prueba 0.9998
# Valor de p_value 0.95
# Valuando probabilidades ...
# Se acepta Ho
# ''

# %% [markdown]
# Para este ejercicio 3, se acepta la $H_0$ dado que el valo de *t_calculado* de $-4.4004$ está muy por debajo del *valor crítico de t* a la derecha de $1.7291$ a $19$ *gl* y con un nivel de confianza del $95$%.
#
# Además con repecto a la probabilidad *p_prueba* alrededor de $0.9998$, es mayor que *p_palue=0.05* entonces se confirma que se acepta $H_0$.

# %% [markdown]
# # Interpretación
#
# * Del ejercicio 1 cuál es la interpretación a un nivel de confianza del 90% y del 99%
# * Del ejercicio 2, que sucede si se aumenta el nivel de confianza al 95% y al 99%.
# * Del ejercicio 3, que pasa si el valor de comparación es 215 en el nivel de colesterol estimado, ¿Se acepta o rechaza $H_0$.
#
# $$
# H_0: \mu \ge 215
# $$
#
# $$
# H_a: \mu < 215
# $$
#
# ¿Porqué se utiliza la distribución *t student * y no distribución normal de z?
#
# Las muestras son pequeñas además de que se supone que no se conoce la desviación estándar de la población.

# %% [markdown]
# # Bibliografía
#
# * Anderson, D., Sweeney, D., & Williams, T. (2008). Estadística para administración y economía Estadística para administración y economía. 10a. Edición. México, D.F: Cengage Learning Editores,S.A. de C.V.
# * Devore, J. L. (2018). Fundamentos de Probabilidad y Estadística. California Polytechnic State University, San Luis Obispo: CENCAGE.
# * Mendenhall, W., Beaver, R. J., & Beaver, B. M. (2010). Introducción a la probabilidad y estadística. México, D.F.: Cengage Learning Editores, S.A. de C.V.
# * ChatGPT
